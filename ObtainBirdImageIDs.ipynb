# %%
# Imports:
import pandas as pd  # DataFrames
import requests as rq  # Send HTTP requests to servers
import re  # Regular expressions
from datetime import date  # To search for images up to today
import time

# Other information:
today = str(date.today())
print("Today's date:", today)
# Out:
# Today's date: 2020-12-22

# %%
# Import the birds for which we have to retrieve images:
bd_path = r"C:\Users\emmav\Documents\AI Master year 1\TMM\Project\BirdsForClassification.txt"
bd = pd.read_csv(bd_path, header=0)
bd.head()
# Out:
#         Species              Scientific   ID
# 0       Dodaars  Tachybaptus ruficollis    2
# 1          Fuut      Podiceps cristatus   91
# 2  Roodhalsfuut      Podiceps grisegena  367
# 3  Geoorde Fuut    Podiceps nigricollis    3
# 4   Aalscholver     Phalacrocorax carbo   58

# %%
# Test searching for images for a bird from the list:
species_id = bd.loc[89,'ID']  # Roodborst

parameters = {'after_date': '2016-01-01',
              'before_date': today,
              'species': species_id,
              'species_group': 1,
              'advanced': 'on',
              'is_validated': 'on',
              'type': 1,
             }

base_url = 'https://waarneming.nl/photos/'

test = rq.Request('GET', base_url, params=parameters).prepare()
print(test.url)

response = rq.get(base_url, parameters)
print(response.text)
# Out:
# https://waarneming.nl/photos/?after_date=2016-01-01&before_date=2020-12-22&species=168&species_group=1&advanced=on&is_validated=on&type=1
# <!DOCTYPE html>
# <html lang="nl">
# <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
#         <meta name="viewport" content="width=device-width, initial-scale=1, user-scalable=no">
#
#
#     <meta name="format-detection" content="telephone=no">
#     <title>Foto's
#         - Waarneming.nl</title>
#
#
#
# <link rel="apple-touch-icon" sizes="180x180" href="/static/favicon/apple-touch-icon.png">
# <link rel="icon" type="image/png" sizes="32x32" href="/static/favicon/favicon-32x32.png">
# <link rel="icon" type="image/png" sizes="16x16" href="/static/favicon/favicon-16x16.png">
# <link rel="manifest" href="/site.webmanifest">
# <link rel="mask-icon" href="/static/favicon/safari-pinned-tab.svg" color="#0066b1">
# <link rel="shortcut icon" href="/static/favicon/favicon.ico">
# <meta name="msapplication-TileColor" content="#0066b1">
# <meta name="msapplication-config" content="/static/favicon/browserconfig.xml">
# <meta name="theme-color" content="#ffffff">
#
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Ubuntu:400,500,700">
#     <link href="/static/plugins/bootstrap/css/bootstrap.css" rel="stylesheet">
#     <!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries -->
#     <!-- WARNING: Respond.js doesn't work if you view the page via file:// -->
#     <!--[if lt IE 9]>
#       <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>
#       <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>
#     <![endif]-->
#     <link rel="stylesheet" href="/static/css/app.css?2898cf76ed946a4e355f118e400417c345901c26">
#     <link href="/static/plugins/multiselect/css/multi-select.css" rel="stylesheet"/>
#     <link rel="stylesheet" href="/static/plugins/toastr/toastr.min.css">
#     <link href="/static/plugins/bootstrap-datepicker/css/bootstrap-datepicker3.min.css" rel="stylesheet">
#     <link href="/static/plugins/fontawesome-pro/css/all.css" rel="stylesheet">
#
#         <script src="https://browser.sentry-cdn.com/5.2.0/bundle.min.js" crossorigin="anonymous"></script>
#         <script>
#             /* global Sentry:true */
#             Sentry.init({dsn: 'https://3fc58d4b0f83468b9566ac463c91ceb4@sentry.zostera.nl/12'});
#         </script>
#
#     <script src="/static/plugins/jquery/jquery.min.js"></script><script src="/static/plugins/bootstrap/js/bootstrap.js"></script>
#     <script src="/jsi18n/"></script>
#     <script src="/static/plugins/bootstrap-datepicker/js/bootstrap-datepicker.min.js"></script>
#     <script src="/static/plugins/multiselect/js/jquery.multi-select.js"></script>
#     <script>window.navAutocollapse = {more: 'Meer'};</script>
#     <script src="/static/js/responsive-tabs.js?2898cf76ed946a4e355f118e400417c345901c26"></script>
#     <script src="/static/js/likephoto.js?2898cf76ed946a4e355f118e400417c345901c26"></script>
#
#     <script id="SITE_INFO" type="application/json">{"name": "Waarneming.nl", "map": {"center": [52.5, 5], "zoom": 8}}</script>
# <script>
#     window.SITE_INFO = JSON.parse(document.getElementById('SITE_INFO').textContent);
# </script>
#
#     <script>
#         $(function () {
#             $('select[multiple]').not('.nomultiselect, .django-select2, .filter-form').multiSelect({
#                 'selectableHeader': '<h4>' + gettext('available') + '</h4>',
#                 'selectionHeader': '<h4>' + gettext('selected') + '</h4>',
#                 'cssClass': 'bootstrap-multiselect'
#             });
#         });
#     </script>
#     <script src="/static/plugins/bootstrap-hover-dropdown.js"></script>
#     <script src="/static/js/global.js?2898cf76ed946a4e355f118e400417c345901c26"></script>
#
#
#         <meta property="og:title" content="Waarneming.nl">
#         <meta property="og:type" content="article">
#         <meta property="og:url" content="https://waarneming.nl/photos/">
#         <meta property="og:site_name" content="Waarneming.nl">
#         <meta property="og:image" content="https://waarneming.nl/static/img/logo/logo-obs-192x192.png">
#         <meta property="og:description" content="Waarneming.nl wil iedereen in staat stellen om natuurwaarnemingen op te slaan en te delen, waardoor de kennis over de natuur toeneemt.">
#
# </head>
#
# <body>
# <div class="app-page">
#
#
#
#
#
#
#
#         <div class="alert alert-primary app-alert-top">
#             <a href="#" data-toggle="modal" data-target="#app-alert-modal" class="mod-stealth">
#                 <div class="container">
#                     <div class="app-alert-flexbox">
#                         <div class="app-alert-flexbox-content">
#                             <i class="fas fa-exclamation-triangle"></i>&nbsp;
#                             Vermijd drukte, houd 1.5 meter afstand en draag een mondkapje. Wissel geen materiaal uit en gebruik je eigen optiek.
#                         </div>
#                     </div>
#                 </div>
#             </a>
#         </div>
#         <div class="modal fade" id="app-alert-modal" tabindex="-1" role="dialog"
#              aria-labelledby="app-alert-modal-label">
#             <div class="modal-dialog" role="document">
#                 <div class="modal-content">
#                     <div class="modal-header">
#                         <button type="button" class="close" data-dismiss="modal" aria-label="Sluiten">
#                             <span aria-hidden="true">&times;</span>
#                         </button>
#                         <h4 class="modal-title">
#                             Vermijd drukte, houd 1.5 meter afstand en draag een mondkapje. Wissel geen materiaal uit en gebruik je eigen optiek.
#                         </h4>
#                     </div>
#                     <div class="modal-body">
#                         <p>In de huidige tijd is het een groot goed voor iedereen om, met inachtneming van gepaste maatregelen, naar buiten te kunnen gaan. Wij roepen iedereen op om de richtlijnen op te volgen, en vooral ook je verstand te gebruiken en je verantwoordelijkheid te nemen.</p>
# <ul>
# <li>Reis niet, ontdek je eigen directe omgeving</li>
# <li>Houd afstand</li>
# <li>Draag een mondkapje</li>
# <li>Gebruik alleen je eigen optiek en materiaal</li>
# </ul>
# <p>Wij zullen niet alle zeldzaamheden verbergen. Daarmee zouden we het ook op ons nemen om op een gegeven moment weer een "sein veilig" te geven. Dat is niet onze rol. Wel zullen we eerder dan gebruikelijk waarnemingen afschermen. Daarbij speelt zeldzaamheid en locatie een rol. Wij volgen de situatie van dag tot dag. Voel je vrij om zelf ook waarnemingen onder embargo in te voeren, deze worden dan pas later gedeeld.</p>
# <p>We weten ook, dat informatie over zeldzaamheden die op Waarneming.nl worden verborgen, via andere kanalen wel gedeeld wordt. Dat kunnen wij niet voorkomen. Pas goed op jezelf, en op elkaar.</p>
#
#                     </div>
#                     <div class="modal-footer">
#                         <button type="button" class="btn btn-default" data-dismiss="modal">
#                             Sluiten
#                         </button>
#                     </div>
#                 </div>
#             </div>
#         </div>
#
#
#     <div class="app-header hidden-xs">
#         <div class="container">
#
#             <div class="row">
#                 <div class="col-sm-6 app-header-col app-header-col-left">
#                     <div class="app-header-brand">
#                         <a href="/">
#
# <img src="/static/img/logo/logo-waarneming-nl.svg" alt="Waarneming.nl" class="app-brand-logo">
# </a>
#                     </div>
#                 </div>
#                 <div class="col-sm-6 app-header-col app-header-col-right">
#                     <div class="app-header-user-info">
#
#                         <div class="dropdown">
#
#
#
#
#                             <button type="button" class="btn btn-link app-btn-language"
#                                     data-target="#app-i18n-select-modal" data-url="/generic/select-language-modal/"
#                                     data-toggle="tooltip" data-placement="bottom"
#                                     title="Kies taal">
#                                 <span class="content">
#                                     NL
#                                 </span>
#                             </button>
#
#                             <button class="btn btn-link dropdown-toggle app-btn-account"
#                                     type="button" id="dropdown-user-info"
#                                     data-toggle="dropdown" aria-haspopup="true" aria-expanded="true">
#
#                                     Log in of registreer
#
#                                 <span class="caret"></span>
#                             </button>
#
#                             <ul class="dropdown-menu dropdown-menu-right" aria-labelledby="dropdown-user-info">
#
#
# <li><a href="/accounts/login/?next=/photos/%3Fafter_date%3D2016-01-01%26before_date%3D2020-12-22%26species%3D168%26species_group%3D1%26advanced%3Don%26is_validated%3Don%26type%3D1">Inloggen</a>
# </li>
# <li><a href="/accounts/signup/">Nieuw account</a></li>
# <li><a href="/accounts/password/reset/">Wachtwoord vergeten?</a></li>
#
#
#                             </ul>
#
#                         </div>
#
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
#
#     <div class="app-navbar">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <nav class="navbar navbar-default global-navbar">
#
#     <div class="container">
#         <!-- Brand and toggle get grouped for better mobile display -->
#         <div class="navbar-header">
#             <button type="button" class="navbar-toggle collapsed" title="Menu"
#                     data-toggle="collapse" data-target="#global-navbar-collapse" aria-expanded="false"
#                     aria-controls="navbar">
#                 <span class="sr-only">Menu</span>
#                 <span class="icon-bar top-bar"></span>
#                 <span class="icon-bar middle-bar"></span>
#                 <span class="icon-bar bottom-bar"></span>
#             </button>
#             <a class="navbar-brand hidden-sm hidden-md hidden-lg" href="/">
#                 <span class="header-xs-title">
#                     <span class="app-navbar-brand">
#
#
# <img src="/static/img/logo/logo-waarneming-nl.svg" alt="Waarneming.nl" class="app-brand-logo">
#
#                     </span>
#                 </span>
#             </a>
#         </div>
#
#         <!-- Collect the nav links, forms, and other content for toggling -->
#         <div class="collapse navbar-collapse" id="global-navbar-collapse">
#
#             <form class="navbar-form navbar-right app-navbar-search-form" role="search" action="/search/">
#                 <div class="input-group hidden-sm hidden-md hidden-lg app-navbar-search-input-group">
#                     <input type="text" class="form-control app-navbar-search-input" placeholder="Zoek"
#                            name="q">
#                     <div class="input-group-btn">
#                         <button class="btn btn-primary" type="submit"><i class="far fa-search"></i></button>
#                     </div>
#                 </div>
#                 <button class="btn btn-primary hidden-xs app-navbar-search-hide js-navbar-search-button" type="button">
#                     <i class="far fa-search"></i>
#                 </button>
#             </form>
#
#             <ul class="nav navbar-nav navbar-left app-navbar-search-hide">
#
#
#                     <li class="visible-xs">
#                         <a href="/accounts/login/">Inloggen</a>
#                     </li>
#                     <li class="visible-xs">
#                         <a href="/accounts/signup/">Nieuw account</a>
#                     </li>
#
#
#                 <li class="dropdown app-navbar-submit-dropdown">
#                     <a href="#"
#    class="dropdown-toggle"
#    data-toggle="dropdown"
#    role="button"
#    aria-haspopup="true"
#    aria-expanded="false">
#     Invoeren
#     <span class="caret"></span>
# </a>
#
#                     <ul class="dropdown-menu">
#                         <li><a href="/fieldwork/observations/create/" title="Voer in">Waarneming</a></li>
#
#
#                     </ul>
#                 </li>
#
#                 <li class="dropdown">
#
#                     <a href="#"
#    class="dropdown-toggle"
#    data-toggle="dropdown"
#    role="button"
#    aria-haspopup="true"
#    aria-expanded="false">
#     Ontdek
#     <span class="caret"></span>
# </a>
#
#                     <ul class="dropdown-menu">
#
#                         <li><a href="/fieldwork/observations/daylist/">Waarnemingen</a></li>
#                         <li><a href="/fieldwork/observations/explore/">Omgeving</a></li>
#
#                         <li class="divider"></li>
#                         <li><a href="/species/search/">Soorten</a>
#                         </li>
#                         <li><a href="/locations/search/">Locaties</a></li>
#
#                         <li class="divider"></li>
#                         <li><a href="/photos/">Foto's</a></li>
#                         <li><a href="/sounds/">Geluiden</a></li>
#
#
#
#                     </ul>
#                 </li>
#
#
#                     <li class="dropdown">
#
#                         <a href="#"
#    class="dropdown-toggle"
#    data-toggle="dropdown"
#    role="button"
#    aria-haspopup="true"
#    aria-expanded="false">
#     Projecten
#     <span class="caret"></span>
# </a>
#
#                         <ul class="dropdown-menu">
#
#                             <li><a href="/projects/">Projecten</a></li>
#
#
#                         </ul>
#                     </li>
#
#                 <li class="dropdown">
#
#                     <a href="#"
#    class="dropdown-toggle"
#    data-toggle="dropdown"
#    role="button"
#    aria-haspopup="true"
#    aria-expanded="false">
#     Over ons
#     <span class="caret"></span>
# </a>
#
#                     <ul class="dropdown-menu">
#                         <li><a href="/pages/mission/">Missie</a></li>
#                         <li><a href="/pages/team/">Team</a></li>
#                         <li><a href="/pages/help/">Help</a></li>
#                         <li><a href="/pages/getting-started/">Snelstart</a></li>
#
#                         <li class="divider"></li>
#                         <li><a href="/stats/">Statistieken</a></li>
#
#                         <li class="divider"></li>
#                         <li><a href="/tos/">Gebruiksvoorwaarden</a></li>
#                         <li><a href="/pages/code-of-conduct/">Gedragscode</a></li>
#                         <li><a href="/pages/privacy/">Privacy-verklaring</a></li>
#                         <li class="divider"></li>
#                         <li><a href="/pages/partners/">Partners</a></li>
#                     </ul>
#                 </li>
#
#                 <li class="dropdown">
#
#                     <a href="#"
#    class="dropdown-toggle"
#    data-toggle="dropdown"
#    role="button"
#    aria-haspopup="true"
#    aria-expanded="false">
#     Community
#     <span class="caret"></span>
# </a>
#
#                     <ul class="dropdown-menu">
#                         <li><a href="/users/search/">Gebruikers</a></li>
#                         <li><a href="/stats/ranking/species/">Ranglijst soorten</a></li>
#                         <li><a href="/subsites/">Subsites</a></li>
#                         <li><a href="/bioblitz/list/">BioBlitzes</a></li>
#
#
#                         <li class="divider"></li>
#
#                         <li><a href="/quiz/create/">Maak je eigen quiz</a></li>
#
#
#
#                         <li class="divider"></li>
#                         <li>
#                             <a href="https://forum.waarneming.nl" target="_blank">
#                                 Forum <i class="far fa-external-link"></i>
#                             </a>
#                         </li>
#                     </ul>
#                 </li>
#
#
#
#
#
#                 <li class="visible-xs">
#                     <a href="#" data-toggle="modal" data-target="#app-i18n-select-modal"
#                        data-url="/generic/select-language-modal/">
#                         Kies taal
#                     </a>
#                 </li>
#
#             </ul>
#
#         </div>
#
#     </div>
#
# </nav>
#
#     </div>
#
#
#
#     <div class="app-content">
#         <div class="container">
#             <div class="app-content-body">
#
#
#
#         <div class="app-content-title">
#
#                 <h1>
#     Foto's
# </h1>
#
#         </div>
#
#
#
#
#
#
#
#     <style>
#         .app-content-filter .row {
#             margin-bottom: 5px;
#         }
#
#         .advanced-filters {
#             display: none;
#         }
#
#         .advanced-filters * {
#             margin-bottom: 5px;
#         }
#     </style>
#
#
#
#
#
# <link rel="stylesheet" href="/static/plugins/select2/css/select2.min.css" />
# <script src="/static/plugins/select2/js/select2.min.js"></script>
# <link rel="stylesheet" href="/static/plugins/select2/select2-bootstrap.min.css" />
# <link rel="stylesheet" href="/static/plugins/select2/select2-patch.css" />
#
#         <script type="text/javascript" src="/static/plugins/select2/js/i18n/nl.js"></script>
# <script type="text/javascript" src="/static/django_select2/django_select2.js"></script>
#         <div class="app-content-filter">
#             <form class="form-inline filter-form" autocomplete="off">
#                 <div>
#
#
#
#
#
#                             <div class="form-group"><label class="sr-only" for="id_after_date">Vanaf</label><input type="text" name="after_date" value="2016-01-01" class="form-control" placeholder="Vanaf" title="" id="id_after_date"></div>
#
#
#
#                             <div class="form-group"><label class="sr-only" for="id_before_date">Tot</label><input type="text" name="before_date" value="2020-12-22" class="form-control" placeholder="Tot" title="" id="id_before_date"></div>
#
#
#
#
#
#
#
#                             <div class="form-group"><label class="sr-only" for="id_species">Soort</label><select name="species" data-minimum-input-length="2" data-allow-clear="true" data-placeholder="selecteer een soort" data-ajax--url="/species/autocomplete/" data-ajax--cache="true" data-ajax--type="GET" data-select2-dependent-fields="species_group" class="form-control django-select2 django-select2-heavy" title="" id="id_species" data-field_id="ImYxMDJkOTYwLTczYWUtNDQ3MC05N2IxLTliOWNlM2FkNjNlMSI:1krdIQ:RybJF4oalmqbZ9L_oMghD1YUKLw">
#   <option value=""></option>
#
#   <option value="168" selected>Roodborst - Erithacus rubecula</option>
#
# </select></div>
#
#
#
#                             <div class="form-group"><label class="sr-only" for="id_species_group">Soortgroep</label><select name="species_group" class="form-control" title="" id="id_species_group">
#   <option value="">Alle soortgroepen</option>
#
#   <option value="1" selected>Vogels</option>
#
#   <option value="2">Zoogdieren</option>
#
#   <option value="3">Reptielen en amfibieën</option>
#
#   <option value="4">Dagvlinders</option>
#
#   <option value="8">Nachtvlinders en micro&#x27;s</option>
#
#   <option value="5">Libellen</option>
#
#   <option value="9">Vissen</option>
#
#   <option value="14">Sprinkhanen en krekels</option>
#
#   <option value="17">Bijen, wespen en mieren</option>
#
#   <option value="18">Vliegen en muggen</option>
#
#   <option value="16">Kevers</option>
#
#   <option value="15">Wantsen, cicaden en plantenluizen</option>
#
#   <option value="6">Insecten (overig)</option>
#
#   <option value="13">Geleedpotigen (overig)</option>
#
#   <option value="7">Weekdieren</option>
#
#   <option value="20">Overige ongewervelden</option>
#
#   <option value="10">Planten</option>
#
#   <option value="19">Algen, wieren en eencelligen</option>
#
#   <option value="12">Mossen en korstmossen</option>
#
#   <option value="11">Paddenstoelen</option>
#
#   <option value="30">Verstoringen</option>
#
# </select></div>
#
#
#
#
#
#                             <div class="form-group"><label class="sr-only" for="id_province">&lt;function ProvinceFilter.__init__.&lt;locals&gt;.&lt;lambda&gt; at 0x7f7fea8834c0&gt;</label><select name="province" class="form-control" title="" id="id_province">
#   <option value="" selected>alle provincies</option>
#
#   <option value="5">Drenthe</option>
#
#   <option value="8">Flevoland</option>
#
#   <option value="3">Friesland</option>
#
#   <option value="7">Gelderland</option>
#
#   <option value="4">Groningen</option>
#
#   <option value="11">Limburg</option>
#
#   <option value="10">Noord-Brabant</option>
#
#   <option value="2">Noord-Holland</option>
#
#   <option value="6">Overijssel</option>
#
#   <option value="1">Utrecht</option>
#
#   <option value="12">Zeeland</option>
#
#   <option value="9">Zuid-Holland</option>
#
# </select></div>
#
#
#
#                             <div class="form-group"><label class="sr-only" for="id_rarity">zeldzaamheid</label><select name="rarity" class="form-control" title="" id="id_rarity">
#   <option value="" selected>alle zeldzaamheden</option>
#
#   <option value="0">onbekend</option>
#
#   <option value="1">&gt;= algemeen</option>
#
#   <option value="2">&gt;= vrij algemeen</option>
#
#   <option value="3">&gt;= zeldzaam</option>
#
#   <option value="4">zeer zeldzaam</option>
#
# </select></div>
#
#
#
#                             <div class="form-group"><label class="sr-only" for="id_search">Zoek</label><input type="text" name="search" class="form-control" placeholder="Zoek" title="Zoek in de naam van soort, familie, locatie, waarnemer of in de notities of externe referentie." id="id_search"></div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                     <button type="submit" class="btn btn-primary">Filter</button>
#                     <a href="." class="btn btn-default">Wis filters</a>
#
#
#                         <div class="form-group"><div class="checkbox"><label for="id_advanced"><input type="checkbox" name="advanced" class="" title="" id="id_advanced" checked> Toon geavanceerd</label></div></div>
#
#                 </div>
#
#                     <div class="advanced-filters">
#
#
#
#
#
#
#
#
#                                 <div class="form-group"><label class="sr-only" for="id_user">Waarnemer</label><input type="text" name="user" class="form-control" placeholder="Waarnemer" title="" id="id_user"></div>
#
#
#
#                                 <div class="form-group"><label class="sr-only" for="id_location">Locatie</label><input type="text" name="location" class="form-control" placeholder="Locatie" title="" id="id_location"></div>
#
#
#
#
#
#
#
#                                 <div class="form-group"><label class="sr-only" for="id_sex">Geslacht</label><select name="sex" class="form-control" title="" id="id_sex">
#   <option value="" selected>alle geslachten</option>
#
#   <option value="U">onbekend</option>
#
#   <option value="M">man</option>
#
#   <option value="F">vrouw</option>
#
# </select></div>
#
#
#
#
#
#
#
#
#
#                                 <div class="form-group"><div class="checkbox"><label for="id_is_validated"><input type="checkbox" name="is_validated" class="" title="" id="id_is_validated" checked> alleen goedgekeurd</label></div></div>
#
#
#
#                                 <div class="form-group"><div class="checkbox"><label for="id_show_only_uncertain"><input type="checkbox" name="show_only_uncertain" class="" title="" id="id_show_only_uncertain"> alleen onzeker</label></div></div>
#
#
#
#                                 <div class="form-group"><label class="sr-only" for="id_type">type</label><select name="type" class="form-control" title="" id="id_type">
#   <option value="">alle types</option>
#
#   <option value="1" selected>Foto</option>
#
#   <option value="2">Tekening</option>
#
#   <option value="3">Spectrogram</option>
#
#   <option value="4">Document</option>
#
# </select></div>
#
#
#
#                                 <div class="form-group"><label class="sr-only" for="id_life_stage">levensstadium</label><select name="life_stage" class="form-control" title="" id="id_life_stage">
#   <option value="" selected>Alle levensstadia</option>
#
#   <option value="UNKNOWN">onbekend</option>
#
#   <option value="ADULT">adult</option>
#
#   <option value="ADULT_SUMMER">adult zomerkleed</option>
#
#   <option value="ADULT_WINTER">adult winterkleed</option>
#
#   <option value="JUVENILE">juveniel</option>
#
#   <option value="SUB_ADULT">subadult</option>
#
#   <option value="FIRST_AUTUMN">eerste najaar</option>
#
#   <option value="FIRST_WINTER">eerste winter</option>
#
#   <option value="FIRST_SUMMER">eerste zomer</option>
#
#   <option value="SECOND_WINTER">tweede winter</option>
#
#   <option value="SECOND_SUMMER">tweede zomer</option>
#
#   <option value="ECLIPS">eclips</option>
#
#   <option value="FIRST_YEAR">eerste jaar</option>
#
#   <option value="FIRST_CY">eerste kalenderjaar</option>
#
#   <option value="SECOND_CY">tweede kalenderjaar</option>
#
#   <option value="THIRD_CY">derde kalenderjaar</option>
#
#   <option value="THIRD_WINTER">derde winter</option>
#
#   <option value="FOURTH_CY">vierde kalenderjaar</option>
#
#   <option value="DEVIANT">afwijkend</option>
#
#   <option value="PULLUS">pullus</option>
#
#   <option value="IMMATURE">onvolwassen</option>
#
#   <option value="SUMMER_PLUMAGE">zomerkleed</option>
#
#   <option value="WINTER_PLUMAGE">winterkleed</option>
#
# </select></div>
#
#
#
#                                 <div class="form-group"><label class="sr-only" for="id_activity">activiteit</label><select name="activity" class="form-control" title="" id="id_activity">
#   <option value="" selected>Alle activiteiten</option>
#
#   <option value="PRESENT">ter plaatse</option>
#
#   <option value="CALLING">roepend</option>
#
#   <option value="EATING">foeragerend</option>
#
#   <option value="PROBABLE_NESTING_PLACE">waarschijnlijke nestplaats</option>
#
#   <option value="OCCUPIED_NEST_WITH_YOUNG">bezet nest met jongen</option>
#
#   <option value="TRANSPORT_FEED_FAECES">transport voedsel of ontlasting</option>
#
#   <option value="RECENTLY_HATCHED_YOUNG">pas uitgevlogen/dons jongen</option>
#
#   <option value="OCCUPIED_NEST">bezet nest</option>
#
#   <option value="DISTRACTION_DISPLAY">afleidingsgedrag</option>
#
#   <option value="WITH_BROOD_PATH">vogel met broedvlek</option>
#
#   <option value="ADULT_IN_TERRITORY">adult in broedbiotoop</option>
#
#   <option value="ALARMING">alarmerend</option>
#
#   <option value="RECENTLY_USED_NEST">recent gebruikt nest</option>
#
#   <option value="NESTBUILDING">nestbouw</option>
#
#   <option value="PAIR_IN_TERRITORY">paar in broedbiotoop</option>
#
#   <option value="COURTSHIP_PAIR_MAITING">baltsend paar (ook paring)</option>
#
#   <option value="OCCUPIED_NEST_WITH_EGGS">bezet nest met eieren</option>
#
#   <option value="SINGING">baltsend / zingend</option>
#
#   <option value="TERRITORIAL_BEHAVIOUR">nestindicerend gedrag</option>
#
#   <option value="TERRITORY">vastgesteld territorium</option>
#
#   <option value="HUNTING">jagend</option>
#
#   <option value="MIGRATING">overvliegend</option>
#
#   <option value="MIGRATING_N">overvliegend noord</option>
#
#   <option value="MIGRATING_S">overvliegend zuid</option>
#
#   <option value="MIGRATING_E">overvliegend oost</option>
#
#   <option value="MIGRATING_W">overvliegend west</option>
#
#   <option value="MIGRATING_SW">overvliegend zuidwest</option>
#
#   <option value="MIGRATING_SE">overvliegend zuidoost</option>
#
#   <option value="MIGRATING_NE">overvliegend noordoost</option>
#
#   <option value="MIGRATING_NW">overvliegend noordwest</option>
#
#   <option value="ROAD_KILL">verkeersslachtoffer</option>
#
#   <option value="BASKING_IN_SUN">zonnend</option>
#
#   <option value="DISCOVERY_DEAD">vondst (dood)</option>
#
#   <option value="WINDFARM_VICTIM">windmolenslachtoffer</option>
#
#   <option value="MOULTING">ruiend</option>
#
#   <option value="WINDOW_VICTIM">raamslachtoffer</option>
#
#   <option value="CATCH_BY_CAT">vangst door kat</option>
#
#   <option value="PREY_DEAD">Prooi (dood)</option>
#
#   <option value="LONGTERM_STAY">pleisterend</option>
#
#   <option value="FLUSHING">opvliegend</option>
#
#   <option value="SLEEPING_AREA">slaapplaats</option>
#
#   <option value="RESTING">rustend</option>
#
#   <option value="DROWNING_VICTIM">verdrinkingsslachtoffer</option>
#
#   <option value="COLOR_RING_BEARING">(kleur)ringdragend</option>
#
#   <option value="SICK_INJURED">ziek/gewond</option>
#
#   <option value="POWERLINE_VICTIM">hoogspanningsleiding slachtoffer</option>
#
#   <option value="BARBED_WIRE_VICTIM">prikkeldraad slachtoffer</option>
#
#   <option value="DESTROYED_NEST">vernietigd nest</option>
#
# </select></div>
#
#
#
#                                 <div class="form-group"><label class="sr-only" for="id_method">Methode</label><select name="method" class="form-control" title="" id="id_method">
#   <option value="" selected>Alle methodes</option>
#
#   <option value="UNKNOWN">onbekend</option>
#
#   <option value="SEEN">gezien</option>
#
#   <option value="HEARD">gehoord</option>
#
#   <option value="SEEN_AND_HEARD">gezien en gehoord</option>
#
#   <option value="TRACKS">sporen</option>
#
#   <option value="CAUGHT">gevangen</option>
#
#   <option value="IN_PELLET">in braakbal</option>
#
#   <option value="SPOTLIGHT_NIGHT_OBSERVATION">zichtwaarneming met zoeklicht</option>
#
#   <option value="CAMERATRAP">met fotoval</option>
#
#   <option value="SOUNDTRAPPED">op geluidsrecorder</option>
#
#   <option value="COLLECTED">verzameld (in collectie)</option>
#
#   <option value="TELEMETRY">telemetrie</option>
#
#   <option value="(e)DNA_BARCODING">(e)dna barcoding</option>
#
#   <option value="INDOORS">binnenshuis</option>
#
#   <option value="ON_FEEDING_PLACE">op voederplaats</option>
#
# </select></div>
#
#
#                     </div>
#
#
#             </form>
#         </div>
#
#
# <br>
# <div class="app-content-section">
#
#
#
#
# <div class="table-container">
#
#
#         <br>
#         <div class="row">
#
#
#                     <div class="col-lg-3 col-md-4 col-sm-6 col-xs-12 app-content-section">
#
#
#
#
#
#
#
#
#
# <figure class="app-ratio-box-4-3 lightbox-gallery">
#     <a href="/media/photo/032/669/32669834.jpg" class="lightbox-gallery-image">
#         <img class="app-ratio-box-image" src="https://old.waarneming.nl/fotonew/4/32669834.jpg?w=500&amp;h=375">
#     </a>
#     <figcaption class="app-photo-row-caption mod-clickthrough" data-url="/species/168/">
#         <div class="truncate">
#             <span class="content">
#
#                 <a href="/photos/32669834/" class="mod-stealth" title="Bekijk foto">
#                     <i class="far fa-camera fa-fw" title="Bekijk foto"></i>
#                 </a>
#
#                 <a href="/species/168/" class="mod-stealth" title="bekijk soort: Roodborst - Erithacus rubecula">
#                     <span class="species-common-name">Roodborst</span> - <i class="species-scientific-name">Erithacus rubecula</i>
#                 </a>
#
#
#
#
#
#
#
#
#
#             </span>
#         </div>
#
#             <div class="truncate">
#                 <span class="content">
#
#
#                             <a href="/locations/1618/" class="mod-stealth"
#                                 title="bekijk gebied: Hollandscheveld (DR)">
#                                  <i class="fas fa-location-arrow fa-fw"></i> Hollandscheveld (DR)
#                              </a>
#
#
#                 </span>
#             </div>
#
#         <div class="truncate">
#             <span class="content">
#                 <a href="/observation/204539019/" class="mod-stealth pull-right" title="toon waarneming">
#                     2020-12-21
#
#                         <i class="fas fa-badge-check validation-A fa-fw" title="goedgekeurd (automatische validatie)"></i>
#
#
#                 </a>
#
#
#                     <a href="/users/97631/" class="mod-stealth" title="bekijk fotograaf">
#                         <i class="fas fa-user fa-fw"></i> Jan Huisjes
#                     </a>
#
#             </span>
#         </div>
#     </figcaption>
# </figure>
#
#                     </div>
#
#
#
#                     <div class="col-lg-3 col-md-4 col-sm-6 col-xs-12 app-content-section">
#
#
#
#
#
#
#
#
#
# <figure class="app-ratio-box-4-3 lightbox-gallery">
#     <a href="/media/photo/032/669/32669588.jpg" class="lightbox-gallery-image">
#         <img class="app-ratio-box-image" src="https://old.waarneming.nl/fotonew/8/32669588.jpg?w=500&amp;h=375">
#     </a>
#     <figcaption class="app-photo-row-caption mod-clickthrough" data-url="/species/168/">
#         <div class="truncate">
#             <span class="content">
#
#                 <a href="/photos/32669588/" class="mod-stealth" title="Bekijk foto">
#                     <i class="far fa-camera fa-fw" title="Bekijk foto"></i>
#                 </a>
#
#                 <a href="/species/168/" class="mod-stealth" title="bekijk soort: Roodborst - Erithacus rubecula">
#                     <span class="species-common-name">Roodborst</span> - <i class="species-scientific-name">Erithacus rubecula</i>
#                 </a>
#
#
#
#
#
#
#
#
#
#             </span>
#         </div>
#
#             <div class="truncate">
#                 <span class="content">
#
#
#                             <a href="/locations/20989/" class="mod-stealth"
#                                 title="bekijk gebied: Dordrecht - 3de Merwedehaven (ZH)">
#                                  <i class="fas fa-location-arrow fa-fw"></i> Dordrecht - 3de Merwedehaven (ZH)
#                              </a>
#
#
#                 </span>
#             </div>
#
#         <div class="truncate">
#             <span class="content">
#                 <a href="/observation/204538357/" class="mod-stealth pull-right" title="toon waarneming">
#                     2020-12-21
#
#                         <i class="fas fa-check-square validation-J fa-fw" title="goedgekeurd (met bewijs)"></i>
#
#
#                 </a>
#
#
#                     <a href="/users/258439/" class="mod-stealth" title="bekijk fotograaf">
#                         <i class="fas fa-user fa-fw"></i> Jacqueline
#                     </a>
#
#             </span>
#         </div>
#     </figcaption>
# </figure>
#
#                     </div>
#
#
#
#                     <div class="col-lg-3 col-md-4 col-sm-6 col-xs-12 app-content-section">
#
#
#
#
#
#
#
#
#
# <figure class="app-ratio-box-4-3 lightbox-gallery">
#     <a href="/media/photo/032/668/32668576.jpg" class="lightbox-gallery-image">
#         <img class="app-ratio-box-image" src="https://old.waarneming.nl/fotonew/6/32668576.jpg?w=500&amp;h=375">
#     </a>
#     <figcaption class="app-photo-row-caption mod-clickthrough" data-url="/species/168/">
#         <div class="truncate">
#             <span class="content">
#
#                 <a href="/photos/32668576/" class="mod-stealth" title="Bekijk foto">
#                     <i class="far fa-camera fa-fw" title="Bekijk foto"></i>
#                 </a>
#
#                 <a href="/species/168/" class="mod-stealth" title="bekijk soort: Roodborst - Erithacus rubecula">
#                     <span class="species-common-name">Roodborst</span> - <i class="species-scientific-name">Erithacus rubecula</i>
#                 </a>
#
#
#
#
#
#
#
#
#
#             </span>
#         </div>
#
#             <div class="truncate">
#                 <span class="content">
#
#
#                             <a href="/locations/34952/" class="mod-stealth"
#                                 title="bekijk gebied: Zwiggelterveld (DR)">
#                                  <i class="fas fa-location-arrow fa-fw"></i> Zwiggelterveld (DR)
#                              </a>
#
#
#                 </span>
#             </div>
#
#         <div class="truncate">
#             <span class="content">
#                 <a href="/observation/204535579/" class="mod-stealth pull-right" title="toon waarneming">
#                     2020-12-21
#
#                         <i class="fas fa-check-square validation-J fa-fw" title="goedgekeurd (met bewijs)"></i>
#
#
#                 </a>
#
#
#                     <a href="/users/143719/" class="mod-stealth" title="bekijk fotograaf">
#                         <i class="fas fa-user fa-fw"></i> Joeri van Eck
#                     </a>
#
#             </span>
#         </div>
#     </figcaption>
# </figure>
#
#                     </div>
#
#
#
#                     <div class="col-lg-3 col-md-4 col-sm-6 col-xs-12 app-content-section">
#
#
#
#
#
#
#
#
#
# <figure class="app-ratio-box-4-3 lightbox-gallery">
#     <a href="/media/photo/032/667/32667591.jpg" class="lightbox-gallery-image">
#         <img class="app-ratio-box-image" src="https://old.waarneming.nl/fotonew/1/32667591.jpg?w=500&amp;h=375">
#     </a>
#     <figcaption class="app-photo-row-caption mod-clickthrough" data-url="/species/168/">
#         <div class="truncate">
#             <span class="content">
#
#                 <a href="/photos/32667591/" class="mod-stealth" title="Bekijk foto">
#                     <i class="far fa-camera fa-fw" title="Bekijk foto"></i>
#                 </a>
#
#                 <a href="/species/168/" class="mod-stealth" title="bekijk soort: Roodborst - Erithacus rubecula">
#                     <span class="species-common-name">Roodborst</span> - <i class="species-scientific-name">Erithacus rubecula</i>
#                 </a>
#
#
#
#
#
#
#
#
#
#             </span>
#         </div>
#
#             <div class="truncate">
#                 <span class="content">
#
#
#                             <a href="/locations/10190/" class="mod-stealth"
#                                 title="bekijk gebied: Vlissingen - Westerzicht (ZL)">
#                                  <i class="fas fa-location-arrow fa-fw"></i> Vlissingen - Westerzicht (ZL)
#                              </a>
#
#
#                 </span>
#             </div>
#
#         <div class="truncate">
#             <span class="content">
#                 <a href="/observation/204531818/" class="mod-stealth pull-right" title="toon waarneming">
#                     2020-12-21
#
#                         <i class="fas fa-badge-check validation-A fa-fw" title="goedgekeurd (automatische validatie)"></i>
#
#
#                 </a>
#
#
#                     <a href="/users/128042/" class="mod-stealth" title="bekijk fotograaf">
#                         <i class="fas fa-user fa-fw"></i> M. Beks Hindriks
#                     </a>
#
#             </span>
#         </div>
#     </figcaption>
# </figure>
#
#                     </div>
#
#
#
#                     <div class="col-lg-3 col-md-4 col-sm-6 col-xs-12 app-content-section">
#
#
#
#
#
#
#
#
#
# <figure class="app-ratio-box-4-3 lightbox-gallery">
#     <a href="/media/photo/032/666/32666978.jpg" class="lightbox-gallery-image">
#         <img class="app-ratio-box-image" src="https://old.waarneming.nl/fotonew/8/32666978.jpg?w=500&amp;h=375">
#     </a>
#     <figcaption class="app-photo-row-caption mod-clickthrough" data-url="/species/168/">
#         <div class="truncate">
#             <span class="content">
#
#                 <a href="/photos/32666978/" class="mod-stealth" title="Bekijk foto">
#                     <i class="far fa-camera fa-fw" title="Bekijk foto"></i>
#                 </a>
#
#                 <a href="/species/168/" class="mod-stealth" title="bekijk soort: Roodborst - Erithacus rubecula">
#                     <span class="species-common-name">Roodborst</span> - <i class="species-scientific-name">Erithacus rubecula</i>
#                 </a>
#
#
#
#
#
#
#
#
#
#             </span>
#         </div>
#
#             <div class="truncate">
#                 <span class="content">
#
#
#                             <a href="/locations/9685/" class="mod-stealth"
#                                 title="bekijk gebied: &#x27;s-Hertogenbosch - Zuiderplas (NB)">
#                                  <i class="fas fa-location-arrow fa-fw"></i> &#x27;s-Hertogenbosch - Zuiderplas (NB)
#                              </a>
#
#
#                 </span>
#             </div>
#
#         <div class="truncate">
#             <span class="content">
#                 <a href="/observation/204529434/" class="mod-stealth pull-right" title="toon waarneming">
#                     2020-12-20
#
#                         <i class="fas fa-badge-check validation-A fa-fw" title="goedgekeurd (automatische validatie)"></i>
#
#
#                 </a>
#
#
#                     <a href="/users/129124/" class="mod-stealth" title="bekijk fotograaf">
#                         <i class="fas fa-user fa-fw"></i> Rogier Albers
#                     </a>
#
#             </span>
#         </div>
#     </figcaption>
# </figure>
#
#                     </div>
#
#
#
#                     <div class="col-lg-3 col-md-4 col-sm-6 col-xs-12 app-content-section">
#
#
#
#
#
#
#
#
#
# <figure class="app-ratio-box-4-3 lightbox-gallery">
#     <a href="/media/photo/032/666/32666968.jpg" class="lightbox-gallery-image">
#         <img class="app-ratio-box-image" src="https://old.waarneming.nl/fotonew/8/32666968.jpg?w=500&amp;h=375">
#     </a>
#     <figcaption class="app-photo-row-caption mod-clickthrough" data-url="/species/168/">
#         <div class="truncate">
#             <span class="content">
#
#                 <a href="/photos/32666968/" class="mod-stealth" title="Bekijk foto">
#                     <i class="far fa-camera fa-fw" title="Bekijk foto"></i>
#                 </a>
#
#                 <a href="/species/168/" class="mod-stealth" title="bekijk soort: Roodborst - Erithacus rubecula">
#                     <span class="species-common-name">Roodborst</span> - <i class="species-scientific-name">Erithacus rubecula</i>
#                 </a>
#
#
#
#
#
#
#
#
#
#             </span>
#         </div>
#
#             <div class="truncate">
#                 <span class="content">
#
#
#                             <a href="/locations/9685/" class="mod-stealth"
#                                 title="bekijk gebied: &#x27;s-Hertogenbosch - Zuiderplas (NB)">
#                                  <i class="fas fa-location-arrow fa-fw"></i> &#x27;s-Hertogenbosch - Zuiderplas (NB)
#                              </a>
#
#
#                 </span>
#             </div>
#
#         <div class="truncate">
#             <span class="content">
#                 <a href="/observation/204529424/" class="mod-stealth pull-right" title="toon waarneming">
#                     2020-12-20
#
#                         <i class="fas fa-badge-check validation-A fa-fw" title="goedgekeurd (automatische validatie)"></i>
#
#
#                 </a>
#
#
#                     <a href="/users/129124/" class="mod-stealth" title="bekijk fotograaf">
#                         <i class="fas fa-user fa-fw"></i> Rogier Albers
#                     </a>
#
#             </span>
#         </div>
#     </figcaption>
# </figure>
#
#                     </div>
#
#
#
#                     <div class="col-lg-3 col-md-4 col-sm-6 col-xs-12 app-content-section">
#
#
#
#
#
#
#
#
#
# <figure class="app-ratio-box-4-3 lightbox-gallery">
#     <a href="/media/photo/032/665/32665986.jpg" class="lightbox-gallery-image">
#         <img class="app-ratio-box-image" src="https://old.waarneming.nl/fotonew/6/32665986.jpg?w=500&amp;h=375">
#     </a>
#     <figcaption class="app-photo-row-caption mod-clickthrough" data-url="/species/168/">
#         <div class="truncate">
#             <span class="content">
#
#                 <a href="/photos/32665986/" class="mod-stealth" title="Bekijk foto">
#                     <i class="far fa-camera fa-fw" title="Bekijk foto"></i>
#                 </a>
#
#                 <a href="/species/168/" class="mod-stealth" title="bekijk soort: Roodborst - Erithacus rubecula">
#                     <span class="species-common-name">Roodborst</span> - <i class="species-scientific-name">Erithacus rubecula</i>
#                 </a>
#
#
#
#
#
#
#
#
#
#             </span>
#         </div>
#
#             <div class="truncate">
#                 <span class="content">
#
#
#                             <a href="/locations/6286/" class="mod-stealth"
#                                 title="bekijk gebied: Alphen aan den Rijn - Kerk en Zanen (ZH)">
#                                  <i class="fas fa-location-arrow fa-fw"></i> Alphen aan den Rijn - Kerk en Zanen (ZH)
#                              </a>
#
#
# ...
#                         <i class="fas fa-badge-check validation-A fa-fw" title="goedgekeurd (automatische validatie)"></i>
#
#
#                 </a>
#
#
#                     <a href="/users/295709/" class="mod-stealth" title="bekijk fotograaf">
#                         <i class="fas fa-user fa-fw"></i> Tom Tijsma
#                     </a>
#
#             </span>
#         </div>
#     </figcaption>
# </figure>
#
#                     </div>
#
#
#
#                     <div class="col-lg-3 col-md-4 col-sm-6 col-xs-12 app-content-section">
#
#
#
#
#
#
#
#
#
# <figure class="app-ratio-box-4-3 lightbox-gallery">
#     <a href="/media/photo/032/654/32654880.jpg" class="lightbox-gallery-image">
#         <img class="app-ratio-box-image" src="https://old.waarneming.nl/fotonew/0/32654880.jpg?w=500&amp;h=375">
#     </a>
#     <figcaption class="app-photo-row-caption mod-clickthrough" data-url="/species/168/">
#         <div class="truncate">
#             <span class="content">
#
#                 <a href="/photos/32654880/" class="mod-stealth" title="Bekijk foto">
#                     <i class="far fa-camera fa-fw" title="Bekijk foto"></i>
#                 </a>
#
#                 <a href="/species/168/" class="mod-stealth" title="bekijk soort: Roodborst - Erithacus rubecula">
#                     <span class="species-common-name">Roodborst</span> - <i class="species-scientific-name">Erithacus rubecula</i>
#                 </a>
#
#
#
#
#
#
#
#
#
#             </span>
#         </div>
#
#             <div class="truncate">
#                 <span class="content">
#
#
#                             <a href="/locations/109265/" class="mod-stealth"
#                                 title="bekijk gebied: Putten - Oldenaller - Klein Oldenaller (GE)">
#                                  <i class="fas fa-location-arrow fa-fw"></i> Putten - Oldenaller - Klein Oldenaller (GE)
#                              </a>
#
#
#                 </span>
#             </div>
#
#         <div class="truncate">
#             <span class="content">
#                 <a href="/observation/204499041/" class="mod-stealth pull-right" title="toon waarneming">
#                     2020-12-20
#
#                         <i class="fas fa-badge-check validation-A fa-fw" title="goedgekeurd (automatische validatie)"></i>
#
#
#                 </a>
#
#
#                     <a href="/users/164545/" class="mod-stealth" title="bekijk fotograaf">
#                         <i class="fas fa-user fa-fw"></i> Marcel de Vries
#                     </a>
#
#             </span>
#         </div>
#     </figcaption>
# </figure>
#
#                     </div>
#
#
#
#                     <div class="col-lg-3 col-md-4 col-sm-6 col-xs-12 app-content-section">
#
#
#
#
#
#
#
#
#
# <figure class="app-ratio-box-4-3 lightbox-gallery">
#     <a href="/media/photo/032/654/32654510.jpg" class="lightbox-gallery-image">
#         <img class="app-ratio-box-image" src="https://old.waarneming.nl/fotonew/0/32654510.jpg?w=500&amp;h=375">
#     </a>
#     <figcaption class="app-photo-row-caption mod-clickthrough" data-url="/species/168/">
#         <div class="truncate">
#             <span class="content">
#
#                 <a href="/photos/32654510/" class="mod-stealth" title="Bekijk foto">
#                     <i class="far fa-camera fa-fw" title="Bekijk foto"></i>
#                 </a>
#
#                 <a href="/species/168/" class="mod-stealth" title="bekijk soort: Roodborst - Erithacus rubecula">
#                     <span class="species-common-name">Roodborst</span> - <i class="species-scientific-name">Erithacus rubecula</i>
#                 </a>
#
#
#
#
#
#
#
#
#
#             </span>
#         </div>
#
#             <div class="truncate">
#                 <span class="content">
#
#
#                             <a href="/locations/18790/" class="mod-stealth"
#                                 title="bekijk gebied: Texel - Staatsbossen - Randweg (NH)">
#                                  <i class="fas fa-location-arrow fa-fw"></i> Texel - Staatsbossen - Randweg (NH)
#                              </a>
#
#
#                 </span>
#             </div>
#
#         <div class="truncate">
#             <span class="content">
#                 <a href="/observation/204498153/" class="mod-stealth pull-right" title="toon waarneming">
#                     2020-12-20
#
#                         <i class="fas fa-badge-check validation-A fa-fw" title="goedgekeurd (automatische validatie)"></i>
#
#
#                 </a>
#
#
#                     <a href="/users/318985/" class="mod-stealth" title="bekijk fotograaf">
#                         <i class="fas fa-user fa-fw"></i> Paul van den Berg
#                     </a>
#
#             </span>
#         </div>
#     </figcaption>
# </figure>
#
#                     </div>
#
#
#         </div>
#
#
#
#
#
#
#
#     <ul class="pagination">
#
#
#             <li class="prev disabled"><a>&laquo;</a></li>
#
#
#
#
#
#
#                 <li class="active">
#                     <a>1</a>
#                 </li>
#
#
#
#                 <li>
#                     <a href="/photos/?after_date=2016-01-01&amp;before_date=2020-12-22&amp;species=168&amp;species_group=1&amp;advanced=on&amp;is_validated=on&amp;type=1&amp;page=2">2</a>
#                 </li>
#
#
#
#                 <li>
#                     <a href="/photos/?after_date=2016-01-01&amp;before_date=2020-12-22&amp;species=168&amp;species_group=1&amp;advanced=on&amp;is_validated=on&amp;type=1&amp;page=3">3</a>
#                 </li>
#
#
#
#                 <li>
#                     <a href="/photos/?after_date=2016-01-01&amp;before_date=2020-12-22&amp;species=168&amp;species_group=1&amp;advanced=on&amp;is_validated=on&amp;type=1&amp;page=4">4</a>
#                 </li>
#
#
#
#                 <li>
#                     <a href="/photos/?after_date=2016-01-01&amp;before_date=2020-12-22&amp;species=168&amp;species_group=1&amp;advanced=on&amp;is_validated=on&amp;type=1&amp;page=5">5</a>
#                 </li>
#
#
#
#                 <li>
#                     <a href="/photos/?after_date=2016-01-01&amp;before_date=2020-12-22&amp;species=168&amp;species_group=1&amp;advanced=on&amp;is_validated=on&amp;type=1&amp;page=6">6</a>
#                 </li>
#
#
#
#                 <li>
#                     <a href="/photos/?after_date=2016-01-01&amp;before_date=2020-12-22&amp;species=168&amp;species_group=1&amp;advanced=on&amp;is_validated=on&amp;type=1&amp;page=7">7</a>
#                 </li>
#
#
#
#                 <li>
#                     <a href="/photos/?after_date=2016-01-01&amp;before_date=2020-12-22&amp;species=168&amp;species_group=1&amp;advanced=on&amp;is_validated=on&amp;type=1&amp;page=8">8</a>
#                 </li>
#
#
#
#                 <li>
#                     <a href="/photos/?after_date=2016-01-01&amp;before_date=2020-12-22&amp;species=168&amp;species_group=1&amp;advanced=on&amp;is_validated=on&amp;type=1&amp;page=9">9</a>
#                 </li>
#
#
#
#                 <li>
#                     <a href="/photos/?after_date=2016-01-01&amp;before_date=2020-12-22&amp;species=168&amp;species_group=1&amp;advanced=on&amp;is_validated=on&amp;type=1&amp;page=10">10</a>
#                 </li>
#
#
#
#                 <li>
#                     <a href="/photos/?after_date=2016-01-01&amp;before_date=2020-12-22&amp;species=168&amp;species_group=1&amp;advanced=on&amp;is_validated=on&amp;type=1&amp;page=11">11</a>
#                 </li>
#
#
#
#                 <li>
#                     <a href="/photos/?after_date=2016-01-01&amp;before_date=2020-12-22&amp;species=168&amp;species_group=1&amp;advanced=on&amp;is_validated=on&amp;type=1&amp;page=12">12</a>
#                 </li>
#
#
#
#
#             <li>
#                 <a href="/photos/?after_date=2016-01-01&amp;before_date=2020-12-22&amp;species=168&amp;species_group=1&amp;advanced=on&amp;is_validated=on&amp;type=1&amp;page=17">&hellip;</a>
#             </li>
#
#
#
#             <li class="last">
#                 <a href="/photos/?after_date=2016-01-01&amp;before_date=2020-12-22&amp;species=168&amp;species_group=1&amp;advanced=on&amp;is_validated=on&amp;type=1&amp;page=21">&raquo;</a>
#             </li>
#
#
#     </ul>
#
#
#
#
#
#
# </div>
#
#
# <script src="/static/plugins/simple-lightbox/simple-lightbox.min.js?version=1.17.1"></script>
# <script>
#     $(function () {
#         $('.lightbox-gallery').each(function () {
#             var $self = $(this);
#             var $img = $('img', $self);
#             $img.data('caption', $('figcaption', $self).html());
#         });
#
#         var images = $('.lightbox-gallery-image');
#         if (images.length > 0) {
#             images.simpleLightbox({
#                 captionSelector: 'img',
#                 captionsData: 'caption',
#                 captionType: 'data',
#                 captionPosition: 'outside',
#                 history: false,
#                 animationSlide: false,
#                 animationSpeed: 0,
#                 widthRatio: 0.95,
#                 heightRatio: 0.80
#             });
#         }
#     });
# </script>
#
#
#
# </div>
#
#
#
#
#             </div>
#         </div>
#     </div>
#
#     <div class="app-footer">
#         <div class="container">
#
#
#
#
#
# <div class="app-footer-content">
#     <div class="row">
#         <div class="col-sm-4">
#             <h5>Mobiele applicaties</h5>
#
#             <p>Gebruik onze gratis mobiele apps om waarnemingen in te voeren op je smartphone of tablet.</p>
#             <p>
#                 <a href="/apps/" class="btn btn-default">
#                     Mobiele applicaties
#                     &nbsp;
#                     <i class="fab fa-apple" title="Apple"></i>
#                     <i class="fab fa-android" title="Android"></i>
#                 </a>
#             </p>
#         </div>
#         <div class="col-sm-5">
#             <h5>Onze partners</h5>
#
#             <p class="app-footer-logo-bar">
#                 <a href="https://www.naturalis.nl" target="_blank">
#                     <img class="mod-grayscale" src="/static/img/logo/logo_naturalis.svg"
#                          alt="Naturalis Biodiversity Center">
#                 </a>
#
#
#                     <a href="http://natuurbank.nl" target="_blank">
#                         <img class="mod-grayscale" src="/static/img/logo/nbnl_109x150.png"
#                              alt="NatuurBank Nederland">
#                     </a>
#
#                     <a href="https://www.ndff.nl" target="_blank">
#                         <img class="mod-grayscale" src="/static/img/logo/ndff_114x103.png"
#                              alt="Nationale Databank Flora en Fauna">
#                     </a>
#
#
#                 <a href="https://zostera.nl" target="_blank">
#                     <img class="mod-grayscale" src="/static/img/logo/zostera_logo_with_name.svg"
#                          alt="Zostera IT &amp; Consultancy">
#                 </a>
#             </p>
#         </div>
#         <div class="col-sm-3 app-footer-partners">
#             <h5>Contact</h5>
#
#             <ul class="list-unstyled">
#                 <li>
#
#                         <a href="mailto:info@waarneming.nl" class="app-link-hidden">
#                             <i class="fas fa-envelope fa-fw"></i>&nbsp; info@waarneming.nl
#                         </a>
#
#                 </li>
#
#                     <li>
#                         <a href="https://twitter.com/waarneming" target="_blank" class="app-link-hidden">
#                             <i class="fab fa-twitter fa-fw"></i>&nbsp; Twitter
#                         </a>
#                     </li>
#
#
#                     <li>
#                         <a href="https://www.facebook.com/waarneming/" target="_blank" class="app-link-hidden">
#                             <i class="fab fa-facebook fa-fw"></i>&nbsp; Facebook
#                         </a>
#                     </li>
#
#             </ul>
#
#             <a href="/donate/" class="btn btn-success">Ondersteun ons en doneer</a>
#         </div>
#     </div>
# </div>
#
# <div style="clear: both"></div>
# <p class="app-footer-powered-by">
#     Powered by <a href="https://observation-international.org" target="_blank">Observation International</a>
#     &copy; 2020
# </p>
#
# <a href="/generic/toggle-desktop-version/"
#    class="btn btn-primary visible-xs">
#
#         Toon desktopversie
#
# </a>
#
#         </div>
#     </div>
# </div>
#
# <script src="/static/plugins/toastr/toastr.min.js"></script>
# <script>
#     /* globals toastr:true */
#     toastr.options = {
#         'positionClass': 'toast-bottom-full-width'
#     };
# </script>
#
#
#
# <div id="language-modal"></div>
#
#     <script id="google-analytics" type="text/javascript">
#         /* eslint-disable */
#         (function (i, s, o, g, r, a, m) {
#             i['GoogleAnalyticsObject'] = r;
#             i[r] = i[r] || function () {
#                 (i[r].q = i[r].q || []).push(arguments)
#             }, i[r].l = 1 * new Date();
#             a = s.createElement(o),
#                 m = s.getElementsByTagName(o)[0];
#             a.async = 1;
#             a.src = g;
#             m.parentNode.insertBefore(a, m)
#         })(window, document, 'script', 'https://www.google-analytics.com/analytics.js', 'ga');
#         ga('create', 'UA-55239-1', 'auto');
#         ga('set', 'forceSSL', true); // Toelichting CBP: Gebruik altijd https voor Google Analytics
#         ga('set', 'anonymizeIp', true); // Toelichting CBP: Zet de IP-maskering aan
#         ga('send', 'pageview');
#     </script>
#
#
#
#     <div class="cookielaw-banner" style="z-index: 99999">
#         <div class="container">
#             <button type="button" class="btn btn-default cookielaw-banner-button js-cookielaw-confirm pull-right">
#                 Ik begrijp het
#             </button>
#             <div class="cookielaw-banner-text btn-align">
#                 Deze website gebruikt cookies om je zo goed mogelijk van dienst te zijn.
#             </div>
#         </div>
#     </div>
#     <script>
#         function createCookie(name, value, days) {
#             var expires;
#
#             if (days) {
#                 var date = new Date();
#                 date.setTime(date.getTime() + (days * 24 * 60 * 60 * 1000));
#                 expires = '; expires=' + date.toGMTString();
#             } else {
#                 expires = '';
#             }
#             document.cookie = encodeURIComponent(name) + '=' + encodeURIComponent(value) + expires + '; path=/';
#         }
#
#         $(function () {
#             $('.js-cookielaw-confirm').on('click', function () {
#                 createCookie('cookielaw_accepted', '1', 10 * 365);
#                 $('.cookielaw-banner').hide();
#             });
#         });
#     </script>
#
#
# <form method="post" action="/accounts/logout/" class="hidden d-none js-logout-form">
#     <input type="hidden" name="csrfmiddlewaretoken" value="1sipWyVcUwqM1RWkLLF4TPidLicECykoljFSnZCPX3JBq1jLkBvzjV8fTcFNN6eZ">
#
#     <input class="app-nav-button-link" type="submit" value="Afmelden">
# </form>
# <script>
#     $(function() {
#         $('.js-logout-link').on('click', function () {
#             $('.js-logout-form').submit();
#             return false;
#         });
#     });
# </script>
#
# </body>
#
# </html>

# %%
# Now we have a response... Let's take the links to photos from it:
regex = 'src="https://old.waarneming.nl/fotonew/([^\.]*)\.jpg'
print("Roodborst ID:", species_id)
sources = re.findall(regex, response.text)
print("Photos found:", len(sources))
print(sources)
# Out:
# Roodborst ID: 168
# Photos found: 24
# ['4/32669834', '8/32669588', '6/32668576', '1/32667591', '8/32666978', '8/32666968', '6/32665986', '7/32665767', '5/32665425', '6/32661866', '0/32658260', '9/32658259', '8/32658258', '4/32657784', '6/32657556', '5/32657555', '4/32657554', '3/32657553', '8/32657048', '0/32656530', '5/32656445', '8/32656408', '0/32654880', '0/32654510']

# %%
# Create a new DataFrame for storing the IDs of the photos:
photo_ids = pd.DataFrame()

# %%
# Add the IDs with to the DataFrame with the scientific name as the column name:
column_name = bd.loc[89,'Scientific']
photo_ids.loc[:,'PhotoID'] = sources
photo_ids.loc[:,'Scientific'] = column_name
photo_ids.head()
# Out:
#       PhotoID          Scientific
# 0  4/32669834  Erithacus rubecula
# 1  8/32669588  Erithacus rubecula
# 2  6/32668576  Erithacus rubecula
# 3  1/32667591  Erithacus rubecula
# 4  8/32666978  Erithacus rubecula

# %%
# Now do it for all species:
url = 'https://waarneming.nl/photos/'
parameters = {'after_date': '2016-01-01',
              'before_date': today,
              'species': 0,
              'species_group': 1,  # Birds
              'advanced': 'on',
              'is_validated': 'on',
              'type': 1,  # Photos
             }
i_counter = 0
photo_df = pd.DataFrame()

# %%
for i, species_id in enumerate(bd.loc[:,'ID']):
    parameters['species'] = species_id  # Search for the current species
    response = rq.get(url, parameters)  # Ask the website
    
    # Retrieve the photo ids:
    regex = 'src="https://old.waarneming.nl/fotonew/([^\.]*)\.jpg'
    photo_ids = re.findall(regex, response.text)
    n_ids = len(photo_ids)
    new_ids = pd.DataFrame(photo_ids, index=None, columns=['ID'])
    
    # Add to DF:
    photo_df = photo_df.append(new_ids, ignore_index=True, sort=False)
    photo_df.loc[i_counter:i_counter+n_ids, 'Scientific'] = bd.loc[i, 'Scientific']
    
    # Update the counter and wait to crawl kindly:
    i_counter += n_ids
    time.sleep(4.95)

# %%
# Export:
photo_df.to_csv("PhotoIDs.txt", index=False)
