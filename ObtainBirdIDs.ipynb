# %% [markdown]
# # Retrieving species IDs and scientific names from Waarneming.nl
# ## By Emma Vriezen | Created on: 2020-11-19 | Last edit on: 2020-12-21

# %%
# Imports:
import pandas as pd  # DataFrames
import requests as rq  # Send HTTP requests to servers
import re  # Regular expressions
import time # Sleep function to allow for waiting between requests

# %%
# Import the bird data, which is now merely a list of 298 species:
bd_path = r"C:\Users\emmav\Documents\AI Master year 1\TMM\Project\BirdInfo.txt"
bd = pd.read_csv(bd_path, header=0, encoding='utf-16')
bd.head()
# Out:
#         Species
# 0       Dodaars
# 1          Fuut
# 2  Roodhalsfuut
# 3  Geoorde Fuut
# 4   Aalscholver

# %% [markdown]
# ### Example request to Waarneming.nl

# %%
# Show the response:
url = "https://waarneming.nl/species/search"
species = bd.loc[238,'Species']
parameters = {'species_group': '1', 'q': species}
response = rq.get(url, parameters)  # From the server, contains species number
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="nl">
# <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
#         <meta name="viewport" content="width=device-width, initial-scale=1, user-scalable=no">
#
#
#     <meta name="format-detection" content="telephone=no">
#     <title>Zoek een soort
#         - Waarneming.nl</title>
#
#
#
# <link rel="apple-touch-icon" sizes="180x180" href="/static/favicon/apple-touch-icon.png">
# <link rel="icon" type="image/png" sizes="32x32" href="/static/favicon/favicon-32x32.png">
# <link rel="icon" type="image/png" sizes="16x16" href="/static/favicon/favicon-16x16.png">
# <link rel="manifest" href="/site.webmanifest">
# <link rel="mask-icon" href="/static/favicon/safari-pinned-tab.svg" color="#0066b1">
# <link rel="shortcut icon" href="/static/favicon/favicon.ico">
# <meta name="msapplication-TileColor" content="#0066b1">
# <meta name="msapplication-config" content="/static/favicon/browserconfig.xml">
# <meta name="theme-color" content="#ffffff">
#
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Ubuntu:400,500,700">
#     <link href="/static/plugins/bootstrap/css/bootstrap.css" rel="stylesheet">
#     <!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries -->
#     <!-- WARNING: Respond.js doesn't work if you view the page via file:// -->
#     <!--[if lt IE 9]>
#       <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>
#       <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>
#     <![endif]-->
#     <link rel="stylesheet" href="/static/css/app.css?2898cf76ed946a4e355f118e400417c345901c26">
#     <link href="/static/plugins/multiselect/css/multi-select.css" rel="stylesheet"/>
#     <link rel="stylesheet" href="/static/plugins/toastr/toastr.min.css">
#     <link href="/static/plugins/bootstrap-datepicker/css/bootstrap-datepicker3.min.css" rel="stylesheet">
#     <link href="/static/plugins/fontawesome-pro/css/all.css" rel="stylesheet">
#
#         <script src="https://browser.sentry-cdn.com/5.2.0/bundle.min.js" crossorigin="anonymous"></script>
#         <script>
#             /* global Sentry:true */
#             Sentry.init({dsn: 'https://3fc58d4b0f83468b9566ac463c91ceb4@sentry.zostera.nl/12'});
#         </script>
#
#     <script src="/static/plugins/jquery/jquery.min.js"></script><script src="/static/plugins/bootstrap/js/bootstrap.js"></script>
#     <script src="/jsi18n/"></script>
#     <script src="/static/plugins/bootstrap-datepicker/js/bootstrap-datepicker.min.js"></script>
#     <script src="/static/plugins/multiselect/js/jquery.multi-select.js"></script>
#     <script>window.navAutocollapse = {more: 'Meer'};</script>
#     <script src="/static/js/responsive-tabs.js?2898cf76ed946a4e355f118e400417c345901c26"></script>
#     <script src="/static/js/likephoto.js?2898cf76ed946a4e355f118e400417c345901c26"></script>
#
#     <script id="SITE_INFO" type="application/json">{"name": "Waarneming.nl", "map": {"center": [52.5, 5], "zoom": 8}}</script>
# <script>
#     window.SITE_INFO = JSON.parse(document.getElementById('SITE_INFO').textContent);
# </script>
#
#     <script>
#         $(function () {
#             $('select[multiple]').not('.nomultiselect, .django-select2, .filter-form').multiSelect({
#                 'selectableHeader': '<h4>' + gettext('available') + '</h4>',
#                 'selectionHeader': '<h4>' + gettext('selected') + '</h4>',
#                 'cssClass': 'bootstrap-multiselect'
#             });
#         });
#     </script>
#     <script src="/static/plugins/bootstrap-hover-dropdown.js"></script>
#     <script src="/static/js/global.js?2898cf76ed946a4e355f118e400417c345901c26"></script>
#
#
#         <meta property="og:title" content="Waarneming.nl">
#         <meta property="og:type" content="article">
#         <meta property="og:url" content="https://waarneming.nl/species/search/">
#         <meta property="og:site_name" content="Waarneming.nl">
#         <meta property="og:image" content="https://waarneming.nl/static/img/logo/logo-obs-192x192.png">
#         <meta property="og:description" content="Waarneming.nl wil iedereen in staat stellen om natuurwaarnemingen op te slaan en te delen, waardoor de kennis over de natuur toeneemt.">
#
# </head>
#
# <body>
# <div class="app-page">
#
#
#
#
#
#
#
#         <div class="alert alert-primary app-alert-top">
#             <a href="#" data-toggle="modal" data-target="#app-alert-modal" class="mod-stealth">
#                 <div class="container">
#                     <div class="app-alert-flexbox">
#                         <div class="app-alert-flexbox-content">
#                             <i class="fas fa-exclamation-triangle"></i>&nbsp;
#                             Vermijd drukte, houd 1.5 meter afstand en draag een mondkapje. Wissel geen materiaal uit en gebruik je eigen optiek.
#                         </div>
#                     </div>
#                 </div>
#             </a>
#         </div>
#         <div class="modal fade" id="app-alert-modal" tabindex="-1" role="dialog"
#              aria-labelledby="app-alert-modal-label">
#             <div class="modal-dialog" role="document">
#                 <div class="modal-content">
#                     <div class="modal-header">
#                         <button type="button" class="close" data-dismiss="modal" aria-label="Sluiten">
#                             <span aria-hidden="true">&times;</span>
#                         </button>
#                         <h4 class="modal-title">
#                             Vermijd drukte, houd 1.5 meter afstand en draag een mondkapje. Wissel geen materiaal uit en gebruik je eigen optiek.
#                         </h4>
#                     </div>
#                     <div class="modal-body">
#                         <p>In de huidige tijd is het een groot goed voor iedereen om, met inachtneming van gepaste maatregelen, naar buiten te kunnen gaan. Wij roepen iedereen op om de richtlijnen op te volgen, en vooral ook je verstand te gebruiken en je verantwoordelijkheid te nemen.</p>
# <ul>
# <li>Reis niet, ontdek je eigen directe omgeving</li>
# <li>Houd afstand</li>
# <li>Draag een mondkapje</li>
# <li>Gebruik alleen je eigen optiek en materiaal</li>
# </ul>
# <p>Wij zullen niet alle zeldzaamheden verbergen. Daarmee zouden we het ook op ons nemen om op een gegeven moment weer een "sein veilig" te geven. Dat is niet onze rol. Wel zullen we eerder dan gebruikelijk waarnemingen afschermen. Daarbij speelt zeldzaamheid en locatie een rol. Wij volgen de situatie van dag tot dag. Voel je vrij om zelf ook waarnemingen onder embargo in te voeren, deze worden dan pas later gedeeld.</p>
# <p>We weten ook, dat informatie over zeldzaamheden die op Waarneming.nl worden verborgen, via andere kanalen wel gedeeld wordt. Dat kunnen wij niet voorkomen. Pas goed op jezelf, en op elkaar.</p>
#
#                     </div>
#                     <div class="modal-footer">
#                         <button type="button" class="btn btn-default" data-dismiss="modal">
#                             Sluiten
#                         </button>
#                     </div>
#                 </div>
#             </div>
#         </div>
#
#
#     <div class="app-header hidden-xs">
#         <div class="container">
#
#             <div class="row">
#                 <div class="col-sm-6 app-header-col app-header-col-left">
#                     <div class="app-header-brand">
#                         <a href="/">
#
# <img src="/static/img/logo/logo-waarneming-nl.svg" alt="Waarneming.nl" class="app-brand-logo">
# </a>
#                     </div>
#                 </div>
#                 <div class="col-sm-6 app-header-col app-header-col-right">
#                     <div class="app-header-user-info">
#
#                         <div class="dropdown">
#
#
#
#
#                             <button type="button" class="btn btn-link app-btn-language"
#                                     data-target="#app-i18n-select-modal" data-url="/generic/select-language-modal/"
#                                     data-toggle="tooltip" data-placement="bottom"
#                                     title="Kies taal">
#                                 <span class="content">
#                                     NL
#                                 </span>
#                             </button>
#
#                             <button class="btn btn-link dropdown-toggle app-btn-account"
#                                     type="button" id="dropdown-user-info"
#                                     data-toggle="dropdown" aria-haspopup="true" aria-expanded="true">
#
#                                     Log in of registreer
#
#                                 <span class="caret"></span>
#                             </button>
#
#                             <ul class="dropdown-menu dropdown-menu-right" aria-labelledby="dropdown-user-info">
#
#
# <li><a href="/accounts/login/?next=/species/search/%3Fspecies_group%3D1%26q%3DGriel">Inloggen</a>
# </li>
# <li><a href="/accounts/signup/">Nieuw account</a></li>
# <li><a href="/accounts/password/reset/">Wachtwoord vergeten?</a></li>
#
#
#                             </ul>
#
#                         </div>
#
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
#
#     <div class="app-navbar">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <nav class="navbar navbar-default global-navbar">
#
#     <div class="container">
#         <!-- Brand and toggle get grouped for better mobile display -->
#         <div class="navbar-header">
#             <button type="button" class="navbar-toggle collapsed" title="Menu"
#                     data-toggle="collapse" data-target="#global-navbar-collapse" aria-expanded="false"
#                     aria-controls="navbar">
#                 <span class="sr-only">Menu</span>
#                 <span class="icon-bar top-bar"></span>
#                 <span class="icon-bar middle-bar"></span>
#                 <span class="icon-bar bottom-bar"></span>
#             </button>
#             <a class="navbar-brand hidden-sm hidden-md hidden-lg" href="/">
#                 <span class="header-xs-title">
#                     <span class="app-navbar-brand">
#
#
# <img src="/static/img/logo/logo-waarneming-nl.svg" alt="Waarneming.nl" class="app-brand-logo">
#
#                     </span>
#                 </span>
#             </a>
#         </div>
#
#         <!-- Collect the nav links, forms, and other content for toggling -->
#         <div class="collapse navbar-collapse" id="global-navbar-collapse">
#
#             <form class="navbar-form navbar-right app-navbar-search-form" role="search" action="/search/">
#                 <div class="input-group hidden-sm hidden-md hidden-lg app-navbar-search-input-group">
#                     <input type="text" class="form-control app-navbar-search-input" placeholder="Zoek"
#                            name="q">
#                     <div class="input-group-btn">
#                         <button class="btn btn-primary" type="submit"><i class="far fa-search"></i></button>
#                     </div>
#                 </div>
#                 <button class="btn btn-primary hidden-xs app-navbar-search-hide js-navbar-search-button" type="button">
#                     <i class="far fa-search"></i>
#                 </button>
#             </form>
#
#             <ul class="nav navbar-nav navbar-left app-navbar-search-hide">
#
#
#                     <li class="visible-xs">
#                         <a href="/accounts/login/">Inloggen</a>
#                     </li>
#                     <li class="visible-xs">
#                         <a href="/accounts/signup/">Nieuw account</a>
#                     </li>
#
#
#                 <li class="dropdown app-navbar-submit-dropdown">
#                     <a href="#"
#    class="dropdown-toggle"
#    data-toggle="dropdown"
#    role="button"
#    aria-haspopup="true"
#    aria-expanded="false">
#     Invoeren
#     <span class="caret"></span>
# </a>
#
#                     <ul class="dropdown-menu">
#                         <li><a href="/fieldwork/observations/create/" title="Voer in">Waarneming</a></li>
#
#
#                     </ul>
#                 </li>
#
#                 <li class="dropdown">
#
#                     <a href="#"
#    class="dropdown-toggle"
#    data-toggle="dropdown"
#    role="button"
#    aria-haspopup="true"
#    aria-expanded="false">
#     Ontdek
#     <span class="caret"></span>
# </a>
#
#                     <ul class="dropdown-menu">
#
#                         <li><a href="/fieldwork/observations/daylist/">Waarnemingen</a></li>
#                         <li><a href="/fieldwork/observations/explore/">Omgeving</a></li>
#
#                         <li class="divider"></li>
#                         <li><a href="/species/search/">Soorten</a>
#                         </li>
#                         <li><a href="/locations/search/">Locaties</a></li>
#
#                         <li class="divider"></li>
#                         <li><a href="/photos/">Foto's</a></li>
#                         <li><a href="/sounds/">Geluiden</a></li>
#
#
#
#                     </ul>
#                 </li>
#
#
#                     <li class="dropdown">
#
#                         <a href="#"
#    class="dropdown-toggle"
#    data-toggle="dropdown"
#    role="button"
#    aria-haspopup="true"
#    aria-expanded="false">
#     Projecten
#     <span class="caret"></span>
# </a>
#
#                         <ul class="dropdown-menu">
#
#                             <li><a href="/projects/">Projecten</a></li>
#
#
#                         </ul>
#                     </li>
#
#                 <li class="dropdown">
#
#                     <a href="#"
#    class="dropdown-toggle"
#    data-toggle="dropdown"
#    role="button"
#    aria-haspopup="true"
#    aria-expanded="false">
#     Over ons
#     <span class="caret"></span>
# </a>
#
#                     <ul class="dropdown-menu">
#                         <li><a href="/pages/mission/">Missie</a></li>
#                         <li><a href="/pages/team/">Team</a></li>
#                         <li><a href="/pages/help/">Help</a></li>
#                         <li><a href="/pages/getting-started/">Snelstart</a></li>
#
#                         <li class="divider"></li>
#                         <li><a href="/stats/">Statistieken</a></li>
#
#                         <li class="divider"></li>
#                         <li><a href="/tos/">Gebruiksvoorwaarden</a></li>
#                         <li><a href="/pages/code-of-conduct/">Gedragscode</a></li>
#                         <li><a href="/pages/privacy/">Privacy-verklaring</a></li>
#                         <li class="divider"></li>
#                         <li><a href="/pages/partners/">Partners</a></li>
#                     </ul>
#                 </li>
#
#                 <li class="dropdown">
#
#                     <a href="#"
#    class="dropdown-toggle"
#    data-toggle="dropdown"
#    role="button"
#    aria-haspopup="true"
#    aria-expanded="false">
#     Community
#     <span class="caret"></span>
# </a>
#
#                     <ul class="dropdown-menu">
#                         <li><a href="/users/search/">Gebruikers</a></li>
#                         <li><a href="/stats/ranking/species/">Ranglijst soorten</a></li>
#                         <li><a href="/subsites/">Subsites</a></li>
#                         <li><a href="/bioblitz/list/">BioBlitzes</a></li>
#
#
#                         <li class="divider"></li>
#
#                         <li><a href="/quiz/create/">Maak je eigen quiz</a></li>
#
#
#
#                         <li class="divider"></li>
#                         <li>
#                             <a href="https://forum.waarneming.nl" target="_blank">
#                                 Forum <i class="far fa-external-link"></i>
#                             </a>
#                         </li>
#                     </ul>
#                 </li>
#
#
#
#
#
#                 <li class="visible-xs">
#                     <a href="#" data-toggle="modal" data-target="#app-i18n-select-modal"
#                        data-url="/generic/select-language-modal/">
#                         Kies taal
#                     </a>
#                 </li>
#
#             </ul>
#
#         </div>
#
#     </div>
#
# </nav>
#
#     </div>
#
#
#
#     <div class="app-content">
#         <div class="container">
#             <div class="app-content-body">
#
#
#
#         <div class="app-content-title">
#
#                 <h1>
#     Zoek een soort
# </h1>
#
#         </div>
#
#
#
#     <form action="/species/search/" class="form">
#         <div class="row">
#             <div class="col-xs-12 col-sm-6">
#                 <div class="input-group">
#                     <input type="text"
#                            class="form-control"
#                            placeholder="Zoek"
#                            value="Griel"
#                            name="q"
#                            autofocus>
#                     <div class="input-group-btn">
#                         <button class="btn btn-primary" type="submit"><i class="far fa-search"></i></button>
#                     </div>
#                 </div>
#             </div>
#             <div class="col-sm-6">
#                 <div class="form-group"><select name="species_group" class="form-control" title="" id="id_species_group">
#   <option value="0">Alle soortgroepen</option>
#
#   <option value="1" selected>Vogels</option>
#
#   <option value="2">Zoogdieren</option>
#
#   <option value="3">Reptielen en amfibieën</option>
#
#   <option value="4">Dagvlinders</option>
#
#   <option value="8">Nachtvlinders en micro&#x27;s</option>
#
#   <option value="5">Libellen</option>
#
#   <option value="9">Vissen</option>
#
#   <option value="14">Sprinkhanen en krekels</option>
#
#   <option value="17">Bijen, wespen en mieren</option>
#
#   <option value="18">Vliegen en muggen</option>
#
#   <option value="16">Kevers</option>
#
#   <option value="15">Wantsen, cicaden en plantenluizen</option>
#
#   <option value="6">Insecten (overig)</option>
#
#   <option value="13">Geleedpotigen (overig)</option>
#
#   <option value="7">Weekdieren</option>
#
#   <option value="20">Overige ongewervelden</option>
#
#   <option value="10">Planten</option>
#
#   <option value="19">Algen, wieren en eencelligen</option>
#
#   <option value="12">Mossen en korstmossen</option>
#
#   <option value="11">Paddenstoelen</option>
#
#   <option value="30">Verstoringen</option>
#
# </select></div>
#             </div>
#         </div>
#         <div class="row">
#             <div class="col-sm-6">
#                 <div class="form-group"><div class="checkbox"><label for="id_deep"><input type="checkbox" name="deep" class="" id="id_deep"> Inclusief hybriden, verzamelsoorten, etc.</label></div></div>
#             </div>
#             <div class="col-sm-6">
#
#                     <div class="form-group"><div class="checkbox"><label for="id_exotic"><input type="checkbox" name="exotic" class="" id="id_exotic"> Inclusief alle niet-inheemse soorten.</label></div></div>
#
#             </div>
#         </div>
#     </form>
#
#
#         <div class="callout callout-warning">Zoekopdrachten met een lengte van 4 tot 6 geven alleen resultaten waarbij begin en einde van woorden overeenkomen.</div>
#
#
#
#         <div class="table-responsive">
#             <table class="table table-compact stupid-table">
#                 <thead>
#                     <tr>
#                         <th data-sort="float" data-sort-onload="yes">#</th>
#                         <th data-sort="string-ins">Naam</th>
#                         <th data-sort="string-ins">Wetenschappelijke naam</th>
#                         <th>Soortgroep</th>
#
#                             <th>Status</th>
#
#                     </tr>
#                 </thead>
#                 <tbody>
#
#                         <tr>
#                             <td data-sort-value="-2" class="sorted-table-index">
#                                 1
#                             </td>
#                             <td data-sort-value="Griel">
#                                 <a href="/species/21/"><span class="species-common-name">Griel</span> - <i class="species-scientific-name">Burhinus oedicnemus</i></a>
#                             </td>
#                             <td>Burhinus oedicnemus</td>
#                             <td>Vogels</td>
#
#                                 <td>
#
#
#                                             <i class="fas fa-flag status-native fa-fw" title="inheems"></i>
#
#                                         <span class="hidden-sm">inheems</span>
#
#                                 </td>
#
#                         </tr>
#
#                 </tbody>
#             </table>
#         </div>
#
# <script src="/static/plugins/stupidtable/stupidtable.min.js"></script>
# <script>
#     // Sort table
#     $(function () {
#         $('.stupid-table').stupidtable().on('aftertablesort', function (event, data) {
#             // Set arrow indicating sort order
#             var $this = $(this);
#             var th = $this.find('th');
#             th.find('.arrow').remove();
#             var dir = $.fn.stupidtable.dir;
#             var arrow = data.direction === dir.ASC ? '&uarr;' : '&darr;';
#             th.eq(data.column).append('<span class="arrow">' + arrow + '</span>');
#             // Set index
#             $('.sorted-table-index', $this).each(function (i) {
#                 $(this).html('' + (i + 1));
#             });
#         });
#     });
# </script>
# <style>
#     th[data-sort] {
#         cursor: pointer;
#     }
#     .sorted-table-index {
#         font-weight: bold;
#     }
# </style>
#
#
#
#         <div class="app-content-section">
#
#
#         <div class="app-gallery-item
#
#                         ">
#
#
#
#
#
#
#
#
#
# <figure class="app-ratio-box-4-3 lightbox-gallery">
#     <a href="/media/photo/002/039/2039122.jpg" class="lightbox-gallery-image">
#         <img class="app-ratio-box-image" src="https://old.waarneming.nl/fotonew/2/2039122.jpg?w=500&amp;h=375">
#     </a>
#     <figcaption class="app-photo-row-caption mod-clickthrough" data-url="/species/21/">
#         <div class="truncate">
#             <span class="content">
#
#                 <a href="/photos/2039122/" class="mod-stealth" title="Bekijk foto">
#                     <i class="far fa-camera fa-fw" title="Bekijk foto"></i>
#                 </a>
#
#                 <a href="/species/21/" class="mod-stealth" title="bekijk soort: Griel - Burhinus oedicnemus">
#                     <span class="species-common-name">Griel</span> - <i class="species-scientific-name">Burhinus oedicnemus</i>
#                 </a>
#
#
#
#
#
#
#
#
#
#             </span>
#         </div>
#
#             <div class="truncate">
#                 <span class="content">
#
#
#                             <a href="/locations/4483/" class="mod-stealth"
#                                 title="bekijk gebied: Oudeland van Strijen (ZH)">
#                                  <i class="fas fa-location-arrow fa-fw"></i> Oudeland van Strijen (ZH)
#                              </a>
#
#
#                 </span>
#             </div>
#
#         <div class="truncate">
#             <span class="content">
#                 <a href="/observation/53784241/" class="mod-stealth pull-right" title="toon waarneming">
#                     2011-04-24
#
#                         <i class="fas fa-check-square validation-J fa-fw" title="goedgekeurd (met bewijs)"></i>
#
#
#                 </a>
#
#
#                     <a href="/users/16732/" class="mod-stealth" title="bekijk fotograaf">
#                         <i class="fas fa-user fa-fw"></i> Arjen Hahn
#                     </a>
#
#             </span>
#         </div>
#     </figcaption>
# </figure>
#
#         </div>
#
#
# </div>
#
#
# <script src="/static/plugins/simple-lightbox/simple-lightbox.min.js?version=1.17.1"></script>
# <script>
#     $(function () {
#         $('.lightbox-gallery').each(function () {
#             var $self = $(this);
#             var $img = $('img', $self);
#             $img.data('caption', $('figcaption', $self).html());
#         });
#
#         var images = $('.lightbox-gallery-image');
#         if (images.length > 0) {
#             images.simpleLightbox({
#                 captionSelector: 'img',
#                 captionsData: 'caption',
#                 captionType: 'data',
#                 captionPosition: 'outside',
#                 history: false,
#                 animationSlide: false,
#                 animationSpeed: 0,
#                 widthRatio: 0.95,
#                 heightRatio: 0.80
#             });
#         }
#     });
# </script>
#
#
#
#
#
#
#             </div>
#         </div>
#     </div>
#
#     <div class="app-footer">
#         <div class="container">
#
#
#
#
#
# <div class="app-footer-content">
#     <div class="row">
#         <div class="col-sm-4">
#             <h5>Mobiele applicaties</h5>
#
#             <p>Gebruik onze gratis mobiele apps om waarnemingen in te voeren op je smartphone of tablet.</p>
#             <p>
#                 <a href="/apps/" class="btn btn-default">
#                     Mobiele applicaties
#                     &nbsp;
#                     <i class="fab fa-apple" title="Apple"></i>
#                     <i class="fab fa-android" title="Android"></i>
#                 </a>
#             </p>
#         </div>
#         <div class="col-sm-5">
#             <h5>Onze partners</h5>
#
#             <p class="app-footer-logo-bar">
#                 <a href="https://www.naturalis.nl" target="_blank">
#                     <img class="mod-grayscale" src="/static/img/logo/logo_naturalis.svg"
#                          alt="Naturalis Biodiversity Center">
#                 </a>
#
#
#                     <a href="http://natuurbank.nl" target="_blank">
#                         <img class="mod-grayscale" src="/static/img/logo/nbnl_109x150.png"
#                              alt="NatuurBank Nederland">
#                     </a>
#
#                     <a href="https://www.ndff.nl" target="_blank">
#                         <img class="mod-grayscale" src="/static/img/logo/ndff_114x103.png"
#                              alt="Nationale Databank Flora en Fauna">
#                     </a>
#
#
#                 <a href="https://zostera.nl" target="_blank">
#                     <img class="mod-grayscale" src="/static/img/logo/zostera_logo_with_name.svg"
#                          alt="Zostera IT &amp; Consultancy">
#                 </a>
#             </p>
#         </div>
#         <div class="col-sm-3 app-footer-partners">
#             <h5>Contact</h5>
#
#             <ul class="list-unstyled">
#                 <li>
#
#                         <a href="mailto:info@waarneming.nl" class="app-link-hidden">
#                             <i class="fas fa-envelope fa-fw"></i>&nbsp; info@waarneming.nl
#                         </a>
#
#                 </li>
#
#                     <li>
#                         <a href="https://twitter.com/waarneming" target="_blank" class="app-link-hidden">
#                             <i class="fab fa-twitter fa-fw"></i>&nbsp; Twitter
#                         </a>
#                     </li>
#
#
#                     <li>
#                         <a href="https://www.facebook.com/waarneming/" target="_blank" class="app-link-hidden">
#                             <i class="fab fa-facebook fa-fw"></i>&nbsp; Facebook
#                         </a>
#                     </li>
#
#             </ul>
#
#             <a href="/donate/" class="btn btn-success">Ondersteun ons en doneer</a>
#         </div>
#     </div>
# </div>
#
# <div style="clear: both"></div>
# <p class="app-footer-powered-by">
#     Powered by <a href="https://observation-international.org" target="_blank">Observation International</a>
#     &copy; 2020
# </p>
#
# <a href="/generic/toggle-desktop-version/"
#    class="btn btn-primary visible-xs">
#
#         Toon desktopversie
#
# </a>
#
#         </div>
#     </div>
# </div>
#
# <script src="/static/plugins/toastr/toastr.min.js"></script>
# <script>
#     /* globals toastr:true */
#     toastr.options = {
#         'positionClass': 'toast-bottom-full-width'
#     };
# </script>
#
#
#
# <div id="language-modal"></div>
#
#     <script id="google-analytics" type="text/javascript">
#         /* eslint-disable */
#         (function (i, s, o, g, r, a, m) {
#             i['GoogleAnalyticsObject'] = r;
#             i[r] = i[r] || function () {
#                 (i[r].q = i[r].q || []).push(arguments)
#             }, i[r].l = 1 * new Date();
#             a = s.createElement(o),
#                 m = s.getElementsByTagName(o)[0];
#             a.async = 1;
#             a.src = g;
#             m.parentNode.insertBefore(a, m)
#         })(window, document, 'script', 'https://www.google-analytics.com/analytics.js', 'ga');
#         ga('create', 'UA-55239-1', 'auto');
#         ga('set', 'forceSSL', true); // Toelichting CBP: Gebruik altijd https voor Google Analytics
#         ga('set', 'anonymizeIp', true); // Toelichting CBP: Zet de IP-maskering aan
#         ga('send', 'pageview');
#     </script>
#
#
#
#     <div class="cookielaw-banner" style="z-index: 99999">
#         <div class="container">
#             <button type="button" class="btn btn-default cookielaw-banner-button js-cookielaw-confirm pull-right">
#                 Ik begrijp het
#             </button>
#             <div class="cookielaw-banner-text btn-align">
#                 Deze website gebruikt cookies om je zo goed mogelijk van dienst te zijn.
#             </div>
#         </div>
#     </div>
#     <script>
#         function createCookie(name, value, days) {
#             var expires;
#
#             if (days) {
#                 var date = new Date();
#                 date.setTime(date.getTime() + (days * 24 * 60 * 60 * 1000));
#                 expires = '; expires=' + date.toGMTString();
#             } else {
#                 expires = '';
#             }
#             document.cookie = encodeURIComponent(name) + '=' + encodeURIComponent(value) + expires + '; path=/';
#         }
#
#         $(function () {
#             $('.js-cookielaw-confirm').on('click', function () {
#                 createCookie('cookielaw_accepted', '1', 10 * 365);
#                 $('.cookielaw-banner').hide();
#             });
#         });
#     </script>
#
#
# <form method="post" action="/accounts/logout/" class="hidden d-none js-logout-form">
#     <input type="hidden" name="csrfmiddlewaretoken" value="OtLUmZKA9sKoubk5HyTsQeryJWB5quzYl0MDUxbXzflZrwlW8UYQfKusTKCk9N05">
#
#     <input class="app-nav-button-link" type="submit" value="Afmelden">
# </form>
# <script>
#     $(function() {
#         $('.js-logout-link').on('click', function () {
#             $('.js-logout-form').submit();
#             return false;
#         });
#     });
# </script>
#
# </body>
#
# </html>

# %%
# Extract the species ID from the example:

# Without scientific name:
# regex = '1\W*</td>\W*<td\s[^"]*"' + species + '">\W*<a\shref="/species/(\d*)/">'
# species_nr = re.findall(regex, response.text)[0]

# With scientific name:
regex = '1\W*</td>\W*<td\s[^"]*"' + species + '">\W*<a\shref="/species/(\d*)/"><[^>]*>' + species + '</span>\s-\s<[^>]*>([^<]*)</i>'
print(regex)
(species_nr, sc_name) = re.findall(regex, response.text)[0]  # Integer that is the index for the current species
print(species_nr)
print(sc_name)
# Out:
# 1\W*</td>\W*<td\s[^"]*"Griel">\W*<a\shref="/species/(\d*)/"><[^>]*>Griel</span>\s-\s<[^>]*>([^<]*)</i>
# 21
# Burhinus oedicnemus

# %%
# Add species number to the dataframe:
bd.loc[238,'Scientific'] = sc_name
bd.loc[238,'ID'] = species_nr
print(bd.iloc[238])
bd.head()
# Out:
# Species                     Griel
# Scientific    Burhinus oedicnemus
# ID                             21
# Name: 238, dtype: object
#         Species Scientific   ID
# 0       Dodaars        NaN  NaN
# 1          Fuut        NaN  NaN
# 2  Roodhalsfuut        NaN  NaN
# 3  Geoorde Fuut        NaN  NaN
# 4   Aalscholver        NaN  NaN

# %% [markdown]
# ### Obtain IDs for all species

# %%
# Loop over all species in the database:
url = "https://waarneming.nl/species/search"

for i, species in enumerate(bd.loc[:,'Species']):
    parameters = {'species_group': '1', 'q': species}
    response = rq.get(url, parameters)
    regex = ('1\W*</td>\W*<td\s[^"]*"'
             + species
             + '">\W*<a\shref="/species/(\d*)/"><[^>]*>'
             + species
             + '</span>\s-\s<[^>]*>([^<]*)</i>'
            ).replace("'", "&#x27;")
    (species_nr, sc_name) = re.findall(regex, response.text)[0]
    bd.loc[i,'Scientific'] = sc_name
    bd.loc[i,'ID'] = species_nr
    print(bd.iloc[i])
    time.sleep(4.95)
# Out:
# Species                      Dodaars
# Scientific    Tachybaptus ruficollis
# ID                                 2
# Name: 0, dtype: object
# Species                     Fuut
# Scientific    Podiceps cristatus
# ID                            91
# Name: 1, dtype: object
# Species             Roodhalsfuut
# Scientific    Podiceps grisegena
# ID                           367
# Name: 2, dtype: object
# Species               Geoorde Fuut
# Scientific    Podiceps nigricollis
# ID                               3
# Name: 3, dtype: object
# Species               Aalscholver
# Scientific    Phalacrocorax carbo
# ID                             58
# Name: 4, dtype: object
# Species                 Roerdomp
# Scientific    Botaurus stellaris
# ID                             1
# Name: 5, dtype: object
# Species                  Woudaap
# Scientific    Ixobrychus minutus
# ID                             4
# Name: 6, dtype: object
# Species                        Kwak
# Scientific    Nycticorax nycticorax
# ID                                5
# Name: 7, dtype: object
# Species       Kleine Zilverreiger
# Scientific       Egretta garzetta
# ID                            132
# Name: 8, dtype: object
# Species       Grote Zilverreiger
# Scientific            Ardea alba
# ID                           115
# Name: 9, dtype: object
# Species       Blauwe Reiger
# Scientific    Ardea cinerea
# ID                       64
# Name: 10, dtype: object
# Species         Purperreiger
# Scientific    Ardea purpurea
# ID                         6
# Name: 11, dtype: object
# Species              Ooievaar
# Scientific    Ciconia ciconia
# ID                          7
# Name: 12, dtype: object
# Species                  Lepelaar
# Scientific    Platalea leucorodia
# ID                              8
# Name: 13, dtype: object
# Species       Knobbelzwaan
# Scientific     Cygnus olor
# ID                     136
# Name: 14, dtype: object
# Species               Kolgans
# Scientific    Anser albifrons
# ID                        139
# Name: 15, dtype: object
# Species       Grauwe Gans
# Scientific    Anser anser
# ID                    104
# Name: 16, dtype: object
# Species       Grote Canadese Gans
# Scientific      Branta canadensis
# ID                            110
# Name: 17, dtype: object
# Species              Brandgans
# Scientific    Branta leucopsis
# ID                          79
# Name: 18, dtype: object
# Species                  Casarca
# Scientific    Tadorna ferruginea
# ID                           236
# Name: 19, dtype: object
# Species              Bergeend
# Scientific    Tadorna tadorna
# ID                         61
# Name: 20, dtype: object
# Species                Smient
# Scientific    Mareca penelope
# ID                        176
# Name: 21, dtype: object
# Species              Krakeend
# Scientific    Mareca strepera
# ID                        142
# Name: 22, dtype: object
# Species       Wintertaling
# Scientific     Anas crecca
# ID                     200
# Name: 23, dtype: object
# Species               Wilde Eend
# Scientific    Anas platyrhynchos
# ID                           198
# Name: 24, dtype: object
# Species       Pijlstaart
# Scientific    Anas acuta
# ID                   160
# Name: 25, dtype: object
# Species               Zomertaling
# Scientific    Spatula querquedula
# ID                            355
# Name: 26, dtype: object
# Species               Slobeend
# Scientific    Spatula clypeata
# ID                         175
# Name: 27, dtype: object
# Species          Krooneend
# Scientific    Netta rufina
# ID                      10
# Name: 28, dtype: object
# Species           Tafeleend
# Scientific    Aythya ferina
# ID                      184
# Name: 29, dtype: object
# Species          Witoogeend
# Scientific    Aythya nyroca
# ID                      772
# Name: 30, dtype: object
# Species              Kuifeend
# Scientific    Aythya fuligula
# ID                        144
# Name: 31, dtype: object
# Species                      Eider
# Scientific    Somateria mollissima
# ID                              11
# Name: 32, dtype: object
# Species               Brilduiker
# Scientific    Bucephala clangula
# ID                            80
# Name: 33, dtype: object
# Species       Middelste Zaagbek
# Scientific      Mergus serrator
# ID                          292
# Name: 34, dtype: object
# Species            Wespendief
# Scientific    Pernis apivorus
# ID                        349
# Name: 35, dtype: object
# Species          Zwarte Wouw
# Scientific    Milvus migrans
# ID                       364
# Name: 36, dtype: object
# Species           Rode Wouw
# Scientific    Milvus milvus
# ID                       12
# Name: 37, dtype: object
# Species                   Zeearend
# Scientific    Haliaeetus albicilla
# ID                             353
# Name: 38, dtype: object
# Species        Bruine Kiekendief
# Scientific    Circus aeruginosus
# ID                            81
# Name: 39, dtype: object
# Species       Blauwe Kiekendief
# Scientific       Circus cyaneus
# ID                           13
# Name: 40, dtype: object
# Species       Grauwe Kiekendief
# Scientific      Circus pygargus
# ID                           14
# Name: 41, dtype: object
# Species                    Havik
# Scientific    Accipiter gentilis
# ID                           117
# Name: 42, dtype: object
# Species               Sperwer
# Scientific    Accipiter nisus
# ID                        178
# Name: 43, dtype: object
# Species           Buizerd
# Scientific    Buteo buteo
# ID                     82
# Name: 44, dtype: object
# Species               Torenvalk
# Scientific    Falco tinnunculus
# ID                          188
# Name: 45, dtype: object
# Species             Boomvalk
# Scientific    Falco subbuteo
# ID                        74
# Name: 46, dtype: object
# Species             Slechtvalk
# Scientific    Falco peregrinus
# ID                         325
# Name: 47, dtype: object
# Species              Korhoen
# Scientific    Lyrurus tetrix
# ID                        15
# Name: 48, dtype: object
# Species             Patrijs
# Scientific    Perdix perdix
# ID                       16
# Name: 49, dtype: object
# Species                 Kwartel
# Scientific    Coturnix coturnix
# ID                          287
# Name: 50, dtype: object
# Species               Waterral
# Scientific    Rallus aquaticus
# ID                         348
# Name: 51, dtype: object
# Species         Porseleinhoen
# Scientific    Porzana porzana
# ID                         17
# Name: 52, dtype: object
# Species       Klein Waterhoen
# Scientific     Zapornia parva
# ID                        276
# Name: 53, dtype: object
# Species       Kleinst Waterhoen
# Scientific     Zapornia pusilla
# ID                          277
# Name: 54, dtype: object
# Species       Kwartelkoning
# Scientific        Crex crex
# ID                       18
# Name: 55, dtype: object
# Species                 Waterhoen
# Scientific    Gallinula chloropus
# ID                            195
# Name: 56, dtype: object
# Species          Meerkoet
# Scientific    Fulica atra
# ID                    149
# Name: 57, dtype: object
# Species       Kraanvogel
# Scientific     Grus grus
# ID                    19
# Name: 58, dtype: object
# Species                 Scholekster
# Scientific    Haematopus ostralegus
# ID                              173
# Name: 59, dtype: object
# Species                  Steltkluut
# Scientific    Himantopus himantopus
# ID                              332
# Name: 60, dtype: object
# Species                        Kluut
# Scientific    Recurvirostra avosetta
# ID                                20
# Name: 61, dtype: object
# Species          Kleine Plevier
# Scientific    Charadrius dubius
# ID                          761
# Name: 62, dtype: object
# Species             Bontbekplevier
# Scientific    Charadrius hiaticula
# ID                              22
# Name: 63, dtype: object
# Species                 Strandplevier
# Scientific    Charadrius alexandrinus
# ID                                 23
# Name: 64, dtype: object
# Species                  Kievit
# Scientific    Vanellus vanellus
# ID                          129
# Name: 65, dtype: object
# Species       Bonte Strandloper
# Scientific      Calidris alpina
# ID                           68
# Name: 66, dtype: object
# Species              Kemphaan
# Scientific    Calidris pugnax
# ID                         24
# Name: 67, dtype: object
# Species                 Watersnip
# Scientific    Gallinago gallinago
# ID                             25
# Name: 68, dtype: object
# Species                 Houtsnip
# Scientific    Scolopax rusticola
# ID                           121
# Name: 69, dtype: object
# Species              Grutto
# Scientific    Limosa limosa
# ID                       26
# Name: 70, dtype: object
# Species                   Wulp
# Scientific    Numenius arquata
# ID                         203
# Name: 71, dtype: object
# Species             Tureluur
# Scientific    Tringa totanus
# ID                        27
# Name: 72, dtype: object
# Species               Oeverloper
# Scientific    Actitis hypoleucos
# ID                           154
# Name: 73, dtype: object
# Species                    Zwartkopmeeuw
# Scientific    Ichthyaetus melanocephalus
# ID                                   363
# Name: 74, dtype: object
# Species                 Dwergmeeuw
# Scientific    Hydrocoloeus minutus
# ID                              84
# Name: 75, dtype: object
# Species                         Kokmeeuw
# Scientific    Chroicocephalus ridibundus
# ID                                   138
# Name: 76, dtype: object
# Species        Stormmeeuw
# Scientific    Larus canus
# ID                    183
# Name: 77, dtype: object
# Species       Kleine Mantelmeeuw
# Scientific          Larus fuscus
# ID                           131
# Name: 78, dtype: object
# Species            Zilvermeeuw
# Scientific    Larus argentatus
# ID                         205
# Name: 79, dtype: object
# Species       Grote Mantelmeeuw
# Scientific        Larus marinus
# ID                          112
# Name: 80, dtype: object
# Species          Drieteenmeeuw
# Scientific    Rissa tridactyla
# ID                         241
# Name: 81, dtype: object
# Species                   Grote Stern
# Scientific    Thalasseus sandvicensis
# ID                                 28
# Name: 82, dtype: object
# Species              Visdief
# Scientific    Sterna hirundo
# ID                        29
# Name: 83, dtype: object
# Species           Noordse Stern
# Scientific    Sterna paradisaea
# ID                           30
# Name: 84, dtype: object
# Species               Dwergstern
# Scientific    Sternula albifrons
# ID                            31
# Name: 85, dtype: object
# Species             Witwangstern
# Scientific    Chlidonias hybrida
# ID                           762
# Name: 86, dtype: object
# Species           Zwarte Stern
# Scientific    Chlidonias niger
# ID                          32
# Name: 87, dtype: object
# Species           Holenduif
# Scientific    Columba oenas
# ID                      119
# Name: 88, dtype: object
# Species               Houtduif
# Scientific    Columba palumbus
# ID                         120
# Name: 89, dtype: object
# Species               Turkse Tortel
# Scientific    Streptopelia decaocto
# ID                              191
# Name: 90, dtype: object
# Species               Zomertortel
# Scientific    Streptopelia turtur
# ID                            342
# Name: 91, dtype: object
# Species               Koekoek
# Scientific    Cuculus canorus
# ID                        137
# Name: 92, dtype: object
# Species         Kerkuil
# Scientific    Tyto alba
# ID                   33
# Name: 93, dtype: object
# Species           Oehoe
# Scientific    Bubo bubo
# ID                  300
# Name: 94, dtype: object
# Species            Steenuil
# Scientific    Athene noctua
# ID                       34
# Name: 95, dtype: object
# Species            Bosuil
# Scientific    Strix aluco
# ID                     77
# Name: 96, dtype: object
# Species         Ransuil
# Scientific    Asio otus
# ID                  310
# Name: 97, dtype: object
# Species             Velduil
# Scientific    Asio flammeus
# ID                       35
# Name: 98, dtype: object
# Species             Ruigpootuil
# Scientific    Aegolius funereus
# ID                          974
# Name: 99, dtype: object
# Species                 Nachtzwaluw
# Scientific    Caprimulgus europaeus
# ID                               36
# Name: 100, dtype: object
# Species       Gierzwaluw
# Scientific     Apus apus
# ID                    97
# Name: 101, dtype: object
# Species            IJsvogel
# Scientific    Alcedo atthis
# ID                       37
# Name: 102, dtype: object
# Species             Bijeneter
# Scientific    Merops apiaster
# ID                       1386
# Name: 103, dtype: object
# Species               Hop
# Scientific    Upupa epops
# ID                     38
# Name: 104, dtype: object
# Species            Draaihals
# Scientific    Jynx torquilla
# ID                        39
# Name: 105, dtype: object
# Species       Groene Specht
# Scientific    Picus viridis
# ID                       40
# Name: 106, dtype: object
# Species           Zwarte Specht
# Scientific    Dryocopus martius
# ID                          759
# Name: 107, dtype: object
# Species       Grote Bonte Specht
# Scientific     Dendrocopos major
# ID                           109
# Name: 108, dtype: object
# Species       Middelste Bonte Specht
# Scientific       Dendrocoptes medius
# ID                               290
# Name: 109, dtype: object
# Species       Kleine Bonte Specht
# Scientific        Dryobates minor
# ID                            271
# Name: 110, dtype: object
# Species           Kuifleeuwerik
# Scientific    Galerida cristata
# ID                           41
# Name: 111, dtype: object
# Species         Boomleeuwerik
# Scientific    Lullula arborea
# ID                         72
# Name: 112, dtype: object
# Species         Veldleeuwerik
# Scientific    Alauda arvensis
# ID                        192
# Name: 113, dtype: object
# Species           Oeverzwaluw
# Scientific    Riparia riparia
# ID                        155
# Name: 114, dtype: object
# Species          Boerenzwaluw
# Scientific    Hirundo rustica
# ID                         65
# Name: 115, dtype: object
# Species             Huiszwaluw
# Scientific    Delichon urbicum
# ID                         123
# Name: 116, dtype: object
# Species              Duinpieper
# Scientific    Anthus campestris
# ID                           43
# Name: 117, dtype: object
# Species             Boompieper
# Scientific    Anthus trivialis
# ID                          73
# Name: 118, dtype: object
# Species             Graspieper
# Scientific    Anthus pratensis
# ID                         103
# Name: 119, dtype: object
# Species       Gele Kwikstaart
# Scientific    Motacilla flava
# ID                         95
# Name: 120, dtype: object
# Species               Engelse Kwikstaart
# Scientific    Motacilla flava flavissima
# ID                                   365
# Name: 121, dtype: object
# Species       Grote Gele Kwikstaart
# Scientific        Motacilla cinerea
# ID                              756
# Name: 122, dtype: object
# Species       Witte Kwikstaart
# Scientific      Motacilla alba
# ID                         202
# Name: 123, dtype: object
# Species                 Rouwkwikstaart
# Scientific    Motacilla alba yarrellii
# ID                                 319
# Name: 124, dtype: object
# Species                  Winterkoning
# Scientific    Troglodytes troglodytes
# ID                                199
# Name: 125, dtype: object
# Species                Heggenmus
# Scientific    Prunella modularis
# ID                           118
# Name: 126, dtype: object
# Species                Roodborst
# Scientific    Erithacus rubecula
# ID                           168
# Name: 127, dtype: object
# Species                  Nachtegaal
# Scientific    Luscinia megarhynchos
# ID                              295
# Name: 128, dtype: object
# Species             Blauwborst
# Scientific    Luscinia svecica
# ID                          62
# Name: 129, dtype: object
# Species          Zwarte Roodstaart
# Scientific    Phoenicurus ochruros
# ID                             356
# Name: 130, dtype: object
# Species          Gekraagde Roodstaart
# Scientific    Phoenicurus phoenicurus
# ID                                 94
# Name: 131, dtype: object
# Species                 Paapje
# Scientific    Saxicola rubetra
# ID                          44
# Name: 132, dtype: object
# Species         Roodborsttapuit
# Scientific    Saxicola rubicola
# ID                           45
# Name: 133, dtype: object
# Species                  Tapuit
# Scientific    Oenanthe oenanthe
# ID                           46
# Name: 134, dtype: object
# Species               Merel
# Scientific    Turdus merula
# ID                      150
# Name: 135, dtype: object
# Species           Kramsvogel
# Scientific    Turdus pilaris
# ID                       143
# Name: 136, dtype: object
# Species             Zanglijster
# Scientific    Turdus philomelos
# ID                          204
# Name: 137, dtype: object
# Species           Grote Lijster
# Scientific    Turdus viscivorus
# ID                          111
# Name: 138, dtype: object
# Species       Cetti's Zanger
# Scientific      Cettia cetti
# ID                       237
# Name: 139, dtype: object
# Species               Graszanger
# Scientific    Cisticola juncidis
# ID                          1111
# Name: 140, dtype: object
# Species        Sprinkhaanzanger
# Scientific    Locustella naevia
# ID                          330
# Name: 141, dtype: object
# Species                          Snor
# Scientific    Locustella luscinioides
# ID                                 47
# Name: 142, dtype: object
# Species                       Rietzanger
# Scientific    Acrocephalus schoenobaenus
# ID                                    48
# Name: 143, dtype: object
# Species                Bosrietzanger
# Scientific    Acrocephalus palustris
# ID                                75
# Name: 144, dtype: object
# Species               Kleine Karekiet
# Scientific    Acrocephalus scirpaceus
# ID                                130
# Name: 145, dtype: object
# Species                  Grote Karekiet
# Scientific    Acrocephalus arundinaceus
# ID                                   49
# Name: 146, dtype: object
# Species                Spotvogel
# Scientific    Hippolais icterina
# ID                           179
# Name: 147, dtype: object
# Species           Orpheusspotvogel
# Scientific    Hippolais polyglotta
# ID                             302
# Name: 148, dtype: object
# Species          Braamsluiper
# Scientific    Curruca curruca
# ID                         78
# Name: 149, dtype: object
# Species                Grasmus
# Scientific    Curruca communis
# ID                         102
# Name: 150, dtype: object
# Species        Tuinfluiter
# Scientific    Sylvia borin
# ID                     189
# Name: 151, dtype: object
# Species                 Zwartkop
# Scientific    Sylvia atricapilla
# ID                           213
# Name: 152, dtype: object
# Species                       Fluiter
# Scientific    Phylloscopus sibilatrix
# ID                                 90
# Name: 153, dtype: object
# Species                     Tjiftjaf
# Scientific    Phylloscopus collybita
# ID                               186
# Name: 154, dtype: object
# Species                        Fitis
# Scientific    Phylloscopus trochilus
# ID                                89
# Name: 155, dtype: object
# Species              Goudhaan
# Scientific    Regulus regulus
# ID                         99
# Name: 156, dtype: object
# Species              Vuurgoudhaan
# Scientific    Regulus ignicapilla
# ID                            347
# Name: 157, dtype: object
# Species       Grauwe Vliegenvanger
# Scientific       Muscicapa striata
# ID                             105
# Name: 158, dtype: object
# Species       Bonte Vliegenvanger
# Scientific     Ficedula hypoleuca
# ID                             69
# Name: 159, dtype: object
# Species                Baardman
# Scientific    Panurus biarmicus
# ID                           50
# Name: 160, dtype: object
# Species                Staartmees
# Scientific    Aegithalos caudatus
# ID                            181
# Name: 161, dtype: object
# Species                Glanskop
# Scientific    Poecile palustris
# ID                           98
# Name: 162, dtype: object
# Species                 Matkop
# Scientific    Poecile montanus
# ID                         148
# Name: 163, dtype: object
# Species                    Kuifmees
# Scientific    Lophophanes cristatus
# ID                              145
# Name: 164, dtype: object
# Species          Zwarte Mees
# Scientific    Periparus ater
# ID                       209
# Name: 165, dtype: object
# Species                Pimpelmees
# Scientific    Cyanistes caeruleus
# ID                            161
# Name: 166, dtype: object
# Species          Koolmees
# Scientific    Parus major
# ID                    140
# Name: 167, dtype: object
# Species           Boomklever
# Scientific    Sitta europaea
# ID                        70
# Name: 168, dtype: object
# Species                 Kortsnavelboomkruiper
# Scientific    Certhia familiaris macrodactyla
# ID                                       1204
# Name: 169, dtype: object
# Species                 Boomkruiper
# Scientific    Certhia brachydactyla
# ID                               71
# Name: 170, dtype: object
# Species             Buidelmees
# Scientific    Remiz pendulinus
# ID                        1206
# Name: 171, dtype: object
# Species             Wielewaal
# Scientific    Oriolus oriolus
# ID                        350
# Name: 172, dtype: object
# Species       Grauwe Klauwier
# Scientific    Lanius collurio
# ID                         51
# Name: 173, dtype: object
# Species             Klapekster
# Scientific    Lanius excubitor
# ID                          52
# Name: 174, dtype: object
# Species                      Gaai
# Scientific    Garrulus glandarius
# ID                             92
# Name: 175, dtype: object
# Species          Ekster
# Scientific    Pica pica
# ID                   87
# Name: 176, dtype: object
# Species                   Kauw
# Scientific    Coloeus monedula
# ID                         126
# Name: 177, dtype: object
# Species              Huiskraai
# Scientific    Corvus splendens
# ID                         261
# Name: 178, dtype: object
# Species                    Roek
# Scientific    Corvus frugilegus
# ID                          167
# Name: 179, dtype: object
# Species        Zwarte Kraai
# Scientific    Corvus corone
# ID                      208
# Name: 180, dtype: object
# Species         Bonte Kraai
# Scientific    Corvus cornix
# ID                       67
# Name: 181, dtype: object
# Species               Raaf
# Scientific    Corvus corax
# ID                      54
# Name: 182, dtype: object
# Species                Spreeuw
# Scientific    Sturnus vulgaris
# ID                         180
# Name: 183, dtype: object
# Species                 Huismus
# Scientific    Passer domesticus
# ID                          122
# Name: 184, dtype: object
# Species               Ringmus
# Scientific    Passer montanus
# ID                        166
# Name: 185, dtype: object
# Species                    Vink
# Scientific    Fringilla coelebs
# ID                          193
# Name: 186, dtype: object
# Species                           Keep
# Scientific    Fringilla montifringilla
# ID                                 127
# Name: 187, dtype: object
# Species       Europese Kanarie
# Scientific     Serinus serinus
# ID                         248
# Name: 188, dtype: object
# Species             Groenling
# Scientific    Chloris chloris
# ID                     261771
# Name: 189, dtype: object
# Species                    Putter
# Scientific    Carduelis carduelis
# ID                            162
# Name: 190, dtype: object
# Species                Sijs
# Scientific    Spinus spinus
# ID                      174
# Name: 191, dtype: object
# Species                    Kneu
# Scientific    Linaria cannabina
# ID                          135
# Name: 192, dtype: object
# Species        Kleine Barmsijs
# Scientific    Acanthis cabaret
# ID                         763
# Name: 193, dtype: object
# Species                Kruisbek
# Scientific    Loxia curvirostra
# ID                          284
# Name: 194, dtype: object
# Species             Grote Kruisbek
# Scientific    Loxia pytyopsittacus
# ID                            1272
# Name: 195, dtype: object
# Species                     Roodmus
# Scientific    Carpodacus erythrinus
# ID                              315
# Name: 196, dtype: object
# Species                Goudvink
# Scientific    Pyrrhula pyrrhula
# ID                          101
# Name: 197, dtype: object
# Species                           Appelvink
# Scientific    Coccothraustes coccothraustes
# ID                                       59
# Name: 198, dtype: object
# Species                  Geelgors
# Scientific    Emberiza citrinella
# ID                             55
# Name: 199, dtype: object
# Species                 Ortolaan
# Scientific    Emberiza hortulana
# ID                            56
# Name: 200, dtype: object
# Species                   Rietgors
# Scientific    Emberiza schoeniclus
# ID                             164
# Name: 201, dtype: object
# Species             Grauwe Gors
# Scientific    Emberiza calandra
# ID                           57
# Name: 202, dtype: object
# Species       Roodkeelduiker
# Scientific    Gavia stellata
# ID                       314
# Name: 203, dtype: object
# Species         Parelduiker
# Scientific    Gavia arctica
# ID                      305
# Name: 204, dtype: object
# Species         IJsduiker
# Scientific    Gavia immer
# ID                    263
# Name: 205, dtype: object
# Species             Kuifduiker
# Scientific    Podiceps auritus
# ID                         286
# Name: 206, dtype: object
# Species       Noordse Stormvogel
# Scientific    Fulmarus glacialis
# ID                           298
# Name: 207, dtype: object
# Species       Grauwe Pijlstormvogel
# Scientific           Ardenna grisea
# ID                             1388
# Name: 208, dtype: object
# Species       Noordse Pijlstormvogel
# Scientific         Puffinus puffinus
# ID                               297
# Name: 209, dtype: object
# Species         Vale Pijlstormvogel
# Scientific    Puffinus mauretanicus
# ID                              369
# Name: 210, dtype: object
# Species              Stormvogeltje
# Scientific    Hydrobates pelagicus
# ID                             335
# Name: 211, dtype: object
# Species          Vaal Stormvogeltje
# Scientific    Oceanodroma leucorhoa
# ID                              343
# Name: 212, dtype: object
# Species         Jan-van-gent
# Scientific    Morus bassanus
# ID                       267
# Name: 213, dtype: object
# Species                 Kuifaalscholver
# Scientific    Phalacrocorax aristotelis
# ID                                  285
# Name: 214, dtype: object
# Species           Koereiger
# Scientific    Bubulcus ibis
# ID                      360
# Name: 215, dtype: object
# Species       Zwarte Ooievaar
# Scientific      Ciconia nigra
# ID                        362
# Name: 216, dtype: object
# Species                Zwarte Ibis
# Scientific    Plegadis falcinellus
# ID                             853
# Name: 217, dtype: object
# Species                      Kleine Zwaan
# Scientific    Cygnus columbianus bewickii
# ID                                    274
# Name: 218, dtype: object
# Species         Wilde Zwaan
# Scientific    Cygnus cygnus
# ID                      351
# Name: 219, dtype: object
# Species       Taigarietgans
# Scientific    Anser fabalis
# ID                      338
# Name: 220, dtype: object
# Species          Toendrarietgans
# Scientific    Anser serrirostris
# ID                           341
# Name: 221, dtype: object
# Species            Kleine Rietgans
# Scientific    Anser brachyrhynchus
# ID                            1384
# Name: 222, dtype: object
# Species              Dwerggans
# Scientific    Anser erythropus
# ID                         244
# Name: 223, dtype: object
# Species               Sneeuwgans
# Scientific    Anser caerulescens
# ID                           327
# Name: 224, dtype: object
# Species               Zwartbuikrotgans
# Scientific    Branta bernicla bernicla
# ID                              243792
# Name: 225, dtype: object
# Species              Witbuikrotgans
# Scientific    Branta bernicla hrota
# ID                              769
# Name: 226, dtype: object
# Species            Roodhalsgans
# Scientific    Branta ruficollis
# ID                          313
# Name: 227, dtype: object
# Species              Topper
# Scientific    Aythya marila
# ID                      187
# Name: 228, dtype: object
# Species                 IJseend
# Scientific    Clangula hyemalis
# ID                          264
# Name: 229, dtype: object
# Species       Zwarte Zee-eend
# Scientific    Melanitta nigra
# ID                        357
# Name: 230, dtype: object
# Species        Grote Zee-eend
# Scientific    Melanitta fusca
# ID                        258
# Name: 231, dtype: object
# Species                 Nonnetje
# Scientific    Mergellus albellus
# ID                           153
# Name: 232, dtype: object
# Species          Grote Zaagbek
# Scientific    Mergus merganser
# ID                         114
# Name: 233, dtype: object
# Species       Ruigpootbuizerd
# Scientific      Buteo lagopus
# ID                        321
# Name: 234, dtype: object
# Species                Visarend
# Scientific    Pandion haliaetus
# ID                          346
# Name: 235, dtype: object
# Species            Roodpootvalk
# Scientific    Falco vespertinus
# ID                          316
# Name: 236, dtype: object
# Species               Smelleken
# Scientific    Falco columbarius
# ID                          326
# Name: 237, dtype: object
# Species                     Griel
# Scientific    Burhinus oedicnemus
# ID                             21
# Name: 238, dtype: object
# Species              Morinelplevier
# Scientific    Charadrius morinellus
# ID                              294
# Name: 239, dtype: object
# Species               Goudplevier
# Scientific    Pluvialis apricaria
# ID                            100
# Name: 240, dtype: object
# Species              Zilverplevier
# Scientific    Pluvialis squatarola
# ID                             206
# Name: 241, dtype: object
# Species                 Kanoet
# Scientific    Calidris canutus
# ID                         125
# Name: 242, dtype: object
# Species       Drieteenstrandloper
# Scientific          Calidris alba
# ID                             83
# Name: 243, dtype: object
# Species       Kleine Strandloper
# Scientific       Calidris minuta
# ID                           133
# Name: 244, dtype: object
# Species       Temmincks Strandloper
# Scientific      Calidris temminckii
# ID                              339
# Name: 245, dtype: object
# Species       Gestreepte Strandloper
# Scientific        Calidris melanotos
# ID                               370
# Name: 246, dtype: object
# Species        Krombekstrandloper
# Scientific    Calidris ferruginea
# ID                            283
# Name: 247, dtype: object
# Species       Paarse Strandloper
# Scientific     Calidris maritima
# ID                           158
# Name: 248, dtype: object
# Species        Breedbekstrandloper
# Scientific    Calidris falcinellus
# ID                             905
# Name: 249, dtype: object
# Species                      Bokje
# Scientific    Lymnocryptes minimus
# ID                             231
# Name: 250, dtype: object
# Species           Rosse Grutto
# Scientific    Limosa lapponica
# ID                         170
# Name: 251, dtype: object
# Species               Regenwulp
# Scientific    Numenius phaeopus
# ID                          163
# Name: 252, dtype: object
# Species           Zwarte Ruiter
# Scientific    Tringa erythropus
# ID                          210
# Name: 253, dtype: object
# Species               Poelruiter
# Scientific    Tringa stagnatilis
# ID                           307
# Name: 254, dtype: object
# Species        Groenpootruiter
# Scientific    Tringa nebularia
# ID                         108
# Name: 255, dtype: object
# Species                Witgat
# Scientific    Tringa ochropus
# ID                        201
# Name: 256, dtype: object
# Species             Bosruiter
# Scientific    Tringa glareola
# ID                         76
# Name: 257, dtype: object
# Species               Steenloper
# Scientific    Arenaria interpres
# ID                           182
# Name: 258, dtype: object
# Species        Grauwe Franjepoot
# Scientific    Phalaropus lobatus
# ID                           253
# Name: 259, dtype: object
# Species            Rosse Franjepoot
# Scientific    Phalaropus fulicarius
# ID                              318
# Name: 260, dtype: object
# Species              Middelste Jager
# Scientific    Stercorarius pomarinus
# ID                               291
# Name: 261, dtype: object
# Species                   Kleine Jager
# Scientific    Stercorarius parasiticus
# ID                                 273
# Name: 262, dtype: object
# Species                 Kleinste Jager
# Scientific    Stercorarius longicaudus
# ID                                 278
# Name: 263, dtype: object
# Species             Grote Jager
# Scientific    Stercorarius skua
# ID                          256
# Name: 264, dtype: object
# Species       Vorkstaartmeeuw
# Scientific        Xema sabini
# ID                       1387
# Name: 265, dtype: object
# Species        Pontische Meeuw
# Scientific    Larus cachinnans
# ID                         937
# Name: 266, dtype: object
# Species           Geelpootmeeuw
# Scientific    Larus michahellis
# ID                          250
# Name: 267, dtype: object
# Species       Kleine Burgemeester
# Scientific       Larus glaucoides
# ID                            272
# Name: 268, dtype: object
# Species       Grote Burgemeester
# Scientific     Larus hyperboreus
# ID                           255
# Name: 269, dtype: object
# Species                   Lachstern
# Scientific    Gelochelidon nilotica
# ID                              368
# Name: 270, dtype: object
# Species              Reuzenstern
# Scientific    Hydroprogne caspia
# ID                           311
# Name: 271, dtype: object
# Species              Witvleugelstern
# Scientific    Chlidonias leucopterus
# ID                               361
# Name: 272, dtype: object
# Species          Zeekoet
# Scientific    Uria aalge
# ID                   354
# Name: 273, dtype: object
# Species              Alk
# Scientific    Alca torda
# ID                   215
# Name: 274, dtype: object
# Species       Zwarte Zeekoet
# Scientific    Cepphus grylle
# ID                      1538
# Name: 275, dtype: object
# Species       Kleine Alk
# Scientific     Alle alle
# ID                   270
# Name: 276, dtype: object
# Species           Papegaaiduiker
# Scientific    Fratercula arctica
# ID                           304
# Name: 277, dtype: object
# Species            Strandleeuwerik
# Scientific    Eremophila alpestris
# ID                             336
# Name: 278, dtype: object
# Species          Grote Pieper
# Scientific    Anthus richardi
# ID                        757
# Name: 279, dtype: object
# Species        Roodkeelpieper
# Scientific    Anthus cervinus
# ID                        755
# Name: 280, dtype: object
# Species             Waterpieper
# Scientific    Anthus spinoletta
# ID                          196
# Name: 281, dtype: object
# Species           Oeverpieper
# Scientific    Anthus petrosus
# ID                        358
# Name: 282, dtype: object
# Species              Noordse Kwikstaart
# Scientific    Motacilla flava thunbergi
# ID                                 1026
# Name: 283, dtype: object
# Species                 Pestvogel
# Scientific    Bombycilla garrulus
# ID                            306
# Name: 284, dtype: object
# Species          Waterspreeuw
# Scientific    Cinclus cinclus
# ID                      84884
# Name: 285, dtype: object
# Species             Beflijster
# Scientific    Turdus torquatus
# ID                         226
# Name: 286, dtype: object
# Species            Koperwiek
# Scientific    Turdus iliacus
# ID                       141
# Name: 287, dtype: object
# Species               Waterrietzanger
# Scientific    Acrocephalus paludicola
# ID                               1129
# Name: 288, dtype: object
# Species        Sperwergrasmus
# Scientific    Curruca nisoria
# ID                        371
# Name: 289, dtype: object
# Species                   Bladkoning
# Scientific    Phylloscopus inornatus
# ID                               227
# Name: 290, dtype: object
# Species       Kleine Vliegenvanger
# Scientific          Ficedula parva
# ID                            1182
# Name: 291, dtype: object
# Species         Taigaboomkruiper
# Scientific    Certhia familiaris
# ID                           337
# Name: 292, dtype: object
# Species                     Frater
# Scientific    Linaria flavirostris
# ID                             249
# Name: 293, dtype: object
# Species         Grote Barmsijs
# Scientific    Acanthis flammea
# ID                         223
# Name: 294, dtype: object
# Species                    IJsgors
# Scientific    Calcarius lapponicus
# ID                             265
# Name: 295, dtype: object
# Species                  Sneeuwgors
# Scientific    Plectrophenax nivalis
# ID                              329
# Name: 296, dtype: object
# Species              Dwerggors
# Scientific    Emberiza pusilla
# ID                         245
# Name: 297, dtype: object

# %%
# Export the list:
bd.to_csv("BirdIDs.txt", index=False)
